# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

DRIVE_BASE = "/content/drive/MyDrive/Thesis"
# Out:
# Mounted at /content/drive

# %%
import os
import json
import numpy as np
import pandas as pd
import torch
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist, mahalanobis
from scipy.special import rel_entr
from itertools import combinations
from transformers import AutoTokenizer, AutoModel

MODEL_NAME      = "bert-large-uncased"
EXCEL_PATH      = os.path.join(DRIVE_BASE, "Sentences.xlsx")
EXCEL_PATH_CS   = os.path.join(DRIVE_BASE, "comp_sci_sentences.xlsx")
EXCEL_PATH_HATE = os.path.join(DRIVE_BASE, "Hate vs Not-Hate.xlsx")
RESULTS_DIR     = os.path.join(DRIVE_BASE, "results", "results_pca_bert_large_sentences")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

COLORS = {
    "Shakespeare":           "#E06C75",
    "Computer Science":      "#61AFEF",
    "Information Security":  "#98C379",
    "Theory of Computation": "#E5C07B",
    "Hate Speech":           "#C678DD",
    "No-Hate Speech":        "#56B6C2",
}
CATEGORIES = list(COLORS.keys())
# Out:
# Device: cpu

# %%
def load_sentences(excel_path, excel_path_cs):
    sentences = {}
    df1 = pd.read_excel(excel_path)
    for col in ["Shakespeare", "Computer Science"]:
        raw = df1[col].dropna().astype(str).tolist()
        sentences[col] = [s.strip() for s in raw if s.strip()]
    df2 = pd.read_excel(excel_path_cs)
    for col in ["Information Security", "Theory of Computation"]:
        raw = df2[col].dropna().astype(str).tolist()
        sentences[col] = [s.strip() for s in raw if s.strip()]
    return sentences


print("Loading sentences ...")
sentences = load_sentences(EXCEL_PATH, EXCEL_PATH_CS)
for cat, sents in sentences.items():
    print(f"  {cat}: {len(sents)} sentences")
# Out:
# Loading sentences ...
#   Shakespeare: 100 sentences
#   Computer Science: 100 sentences
#   Information Security: 100 sentences
#   Theory of Computation: 100 sentences

# %%
def load_model(model_name):
    print(f"Loading model: {model_name} ...")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    model.to(DEVICE)
    model.eval()
    hidden_size = model.config.hidden_size
    print(f"  Model loaded  (hidden dim = {hidden_size})")
    return tokenizer, model


tokenizer, model = load_model(MODEL_NAME)
# Out:
# Loading model: bert-large-uncased ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-large-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   Model loaded  (hidden dim = 1024)

# %%
def extract_embeddings(sentences_dict, tokenizer, model):
    all_embeddings, all_labels = [], []

    with torch.no_grad():
        for category, sents in sentences_dict.items():
            print(f"  Encoding {len(sents)} '{category}' sentences ...")
            for idx, sent in enumerate(sents):
                inputs = tokenizer(
                    sent,
                    return_tensors="pt",
                    truncation=True,
                    max_length=128,
                    padding="max_length",
                )
                inputs = {k: v.to(DEVICE) for k, v in inputs.items()}

                outputs = model(**inputs)
                last_hidden = outputs.last_hidden_state  # (1, seq_len, 1024)

                attn = inputs["attention_mask"].unsqueeze(-1).to(last_hidden.dtype)
                masked = last_hidden * attn
                pooled = masked.sum(dim=1) / attn.sum(dim=1)

                vec = pooled.squeeze(0).float().cpu().numpy()
                all_embeddings.append(vec)
                all_labels.append(category)

                if (idx + 1) % 10 == 0:
                    print(f"    [{category}] {idx+1}/{len(sents)} done")

    embeddings = np.array(all_embeddings)
    labels     = np.array(all_labels)
    print(f"  Total embeddings: {embeddings.shape}")
    return embeddings, labels


print("Extracting embeddings ...")
os.makedirs(RESULTS_DIR, exist_ok=True)
embeddings, labels = extract_embeddings(sentences, tokenizer, model)

np.save(os.path.join(RESULTS_DIR, "embeddings.npy"), embeddings)
np.save(os.path.join(RESULTS_DIR, "labels.npy"), labels)
print(f"  Saved embeddings: {embeddings.shape}")
# Out:
# Extracting embeddings ...
#   Encoding 100 'Shakespeare' sentences ...
#     [Shakespeare] 10/100 done
#     [Shakespeare] 20/100 done
#     [Shakespeare] 30/100 done
#     [Shakespeare] 40/100 done
#     [Shakespeare] 50/100 done
#     [Shakespeare] 60/100 done
#     [Shakespeare] 70/100 done
#     [Shakespeare] 80/100 done
#     [Shakespeare] 90/100 done
#     [Shakespeare] 100/100 done
#   Encoding 100 'Computer Science' sentences ...
#     [Computer Science] 10/100 done
#     [Computer Science] 20/100 done
#     [Computer Science] 30/100 done
#     [Computer Science] 40/100 done
#     [Computer Science] 50/100 done
#     [Computer Science] 60/100 done
#     [Computer Science] 70/100 done
#     [Computer Science] 80/100 done
#     [Computer Science] 90/100 done
#     [Computer Science] 100/100 done
#   Encoding 100 'Information Security' sentences ...
#     [Information Security] 10/100 done
#     [Information Security] 20/100 done
#     [Information Security] 30/100 done
#     [Information Security] 40/100 done
#     [Information Security] 50/100 done
#     [Information Security] 60/100 done
#     [Information Security] 70/100 done
#     [Information Security] 80/100 done
#     [Information Security] 90/100 done
#     [Information Security] 100/100 done
#   Encoding 100 'Theory of Computation' sentences ...
#     [Theory of Computation] 10/100 done
#     [Theory of Computation] 20/100 done
#     [Theory of Computation] 30/100 done
#     [Theory of Computation] 40/100 done
#     [Theory of Computation] 50/100 done
#     [Theory of Computation] 60/100 done
#     [Theory of Computation] 70/100 done
#     [Theory of Computation] 80/100 done
#     [Theory of Computation] 90/100 done
#     [Theory of Computation] 100/100 done
#   Total embeddings: (400, 1024)
#   Saved embeddings: (400, 1024)

# %%
def load_hate_sentences(excel_path_hate):
    df = pd.read_excel(excel_path_hate)
    hate_sents = {}
    for col in ["Hate Speech", "No-Hate Speech"]:
        raw = df[col].dropna().astype(str).tolist()
        hate_sents[col] = [s.strip() for s in raw if s.strip()]
    return hate_sents


print("Loading hate/no-hate sentences ...")
hate_sentences = load_hate_sentences(EXCEL_PATH_HATE)
for cat, sents in hate_sentences.items():
    print(f"  {cat}: {len(sents)} sentences")

print("Extracting hate/no-hate embeddings ...")
hate_embeddings, hate_labels = extract_embeddings(hate_sentences, tokenizer, model)

np.save(os.path.join(RESULTS_DIR, "hate_embeddings.npy"), hate_embeddings)
np.save(os.path.join(RESULTS_DIR, "hate_labels.npy"), hate_labels)
print(f"  Saved hate embeddings: {hate_embeddings.shape}")

del model
del tokenizer
if torch.cuda.is_available():
    torch.cuda.empty_cache()
print("  Model unloaded, GPU memory freed.")
# Out:
# Loading hate/no-hate sentences ...
#   Hate Speech: 100 sentences
#   No-Hate Speech: 100 sentences
# Extracting hate/no-hate embeddings ...
#   Encoding 100 'Hate Speech' sentences ...
#     [Hate Speech] 10/100 done
#     [Hate Speech] 20/100 done
#     [Hate Speech] 30/100 done
#     [Hate Speech] 40/100 done
#     [Hate Speech] 50/100 done
#     [Hate Speech] 60/100 done
#     [Hate Speech] 70/100 done
#     [Hate Speech] 80/100 done
#     [Hate Speech] 90/100 done
#     [Hate Speech] 100/100 done
#   Encoding 100 'No-Hate Speech' sentences ...
#     [No-Hate Speech] 10/100 done
#     [No-Hate Speech] 20/100 done
#     [No-Hate Speech] 30/100 done
#     [No-Hate Speech] 40/100 done
#     [No-Hate Speech] 50/100 done
#     [No-Hate Speech] 60/100 done
#     [No-Hate Speech] 70/100 done
#     [No-Hate Speech] 80/100 done
#     [No-Hate Speech] 90/100 done
#     [No-Hate Speech] 100/100 done
#   Total embeddings: (200, 1024)
#   Saved hate embeddings: (200, 1024)
#   Model unloaded, GPU memory freed.

# %%
import os, json, numpy as np, pandas as pd, torch, matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, silhouette_samples
from scipy.spatial.distance import cdist, mahalanobis
from scipy.special import rel_entr
from itertools import combinations

if "DRIVE_BASE" not in globals():
    DRIVE_BASE = "/content/drive/MyDrive/thesis"
if "MODEL_NAME" not in globals():
    MODEL_NAME = "bert-large-uncased"
if "RESULTS_DIR" not in globals():
    RESULTS_DIR = os.path.join(DRIVE_BASE, "results", "results_pca_bert_large_sentences")
if "EXCEL_PATH" not in globals():
    EXCEL_PATH = os.path.join(DRIVE_BASE, "Sentences.xlsx")
if "EXCEL_PATH_CS" not in globals():
    EXCEL_PATH_CS = os.path.join(DRIVE_BASE, "comp_sci_sentences.xlsx")
if "EXCEL_PATH_HATE" not in globals():
    EXCEL_PATH_HATE = os.path.join(DRIVE_BASE, "Hate vs Not-Hate.xlsx")
if "COLORS" not in globals():
    COLORS = {
        "Shakespeare":           "#E06C75",
        "Computer Science":      "#61AFEF",
        "Information Security":  "#98C379",
        "Theory of Computation": "#E5C07B",
        "Hate Speech":           "#C678DD",
        "No-Hate Speech":        "#56B6C2",
    }

os.makedirs(RESULTS_DIR, exist_ok=True)

embeddings      = np.load(os.path.join(RESULTS_DIR, "embeddings.npy"))
labels          = np.load(os.path.join(RESULTS_DIR, "labels.npy"),      allow_pickle=True)
hate_embeddings = np.load(os.path.join(RESULTS_DIR, "hate_embeddings.npy"))
hate_labels     = np.load(os.path.join(RESULTS_DIR, "hate_labels.npy"), allow_pickle=True)

print(f"Loaded embeddings: {embeddings.shape}, hate: {hate_embeddings.shape}")
# Out:
# Loaded embeddings: (400, 1024), hate: (200, 1024)

# %%
ALL_CATS = ["Shakespeare", "Computer Science", "Information Security",
            "Theory of Computation", "Hate Speech", "No-Hate Speech"]

all_embeddings = np.vstack([embeddings, hate_embeddings])
all_labels     = np.concatenate([labels, hate_labels])

print(f"Combined embeddings: {all_embeddings.shape}")
for cat in ALL_CATS:
    print(f"  {cat}: {(all_labels == cat).sum()}")

def reload_sentences_map():
    sm = {}
    df1 = pd.read_excel(EXCEL_PATH)
    for col in ["Shakespeare", "Computer Science"]:
        raw = df1[col].dropna().astype(str).tolist()
        sm[col] = [s.strip() for s in raw if s.strip()]
    df2 = pd.read_excel(EXCEL_PATH_CS)
    for col in ["Information Security", "Theory of Computation"]:
        raw = df2[col].dropna().astype(str).tolist()
        sm[col] = [s.strip() for s in raw if s.strip()]
    df3 = pd.read_excel(EXCEL_PATH_HATE)
    for col in ["Hate Speech", "No-Hate Speech"]:
        raw = df3[col].dropna().astype(str).tolist()
        sm[col] = [s.strip() for s in raw if s.strip()]
    return sm

sentences_map = reload_sentences_map()
cat_counters  = {cat: 0 for cat in sentences_map}
all_sentences = []
for cat in all_labels:
    all_sentences.append(sentences_map[cat][cat_counters[cat]])
    cat_counters[cat] += 1
all_sentences = np.array(all_sentences)
print(f"Sentences aligned: {len(all_sentences)}")

DIR_DIST = os.path.join(RESULTS_DIR, "distance_metrics");  os.makedirs(DIR_DIST,  exist_ok=True)
DIR_KL   = os.path.join(RESULTS_DIR, "kl_divergence");     os.makedirs(DIR_KL,    exist_ok=True)
DIR_SIL  = os.path.join(RESULTS_DIR, "silhouette");        os.makedirs(DIR_SIL,   exist_ok=True)
DIR_PCA  = os.path.join(RESULTS_DIR, "pca_plots");         os.makedirs(DIR_PCA,   exist_ok=True)
DIR_OVER = os.path.join(RESULTS_DIR, "overlap");           os.makedirs(DIR_OVER,  exist_ok=True)
print("Subfolders ready.")

PAIRS = [
    ("Computer Science",      "Shakespeare"),
    ("Theory of Computation", "Information Security"),
    ("Hate Speech",           "No-Hate Speech"),
]
# Out:
# Combined embeddings: (600, 1024)
#   Shakespeare: 100
#   Computer Science: 100
#   Information Security: 100
#   Theory of Computation: 100
#   Hate Speech: 100
#   No-Hate Speech: 100
# Sentences aligned: 600
# Subfolders ready.

# %%
def compute_distances(emb, labs, tag, results_dir, n_pca=50):
    class_names = [c for c in ALL_CATS if c in set(labs)]
    class_data  = {c: emb[labs == c] for c in class_names}
    class_means = {c: d.mean(axis=0) for c, d in class_data.items()}

    n_components  = min(n_pca, emb.shape[0] - 1, emb.shape[1])
    pca50         = PCA(n_components=n_components)
    emb_r         = pca50.fit_transform(emb)
    var_explained = pca50.explained_variance_ratio_.sum()
    print(f"  PCA-{n_components} variance explained: {var_explained:.1%}")

    class_data_r  = {c: emb_r[labs == c] for c in class_names}
    class_means_r = {c: d.mean(axis=0) for c, d in class_data_r.items()}

    def _euc_cos(cdata, cmeans):
        intra_e, intra_c, inter_e, inter_c = {}, {}, {}, {}
        for c in class_names:
            d = cdata[c]; n = d.shape[0]
            triu = np.triu_indices(n, k=1)
            dmat_e = cdist(d, d, "euclidean")
            intra_e[c] = dmat_e[triu].mean() if len(triu[0]) > 0 else 0.0
            dmat_c = cdist(d, d, "cosine")
            intra_c[c] = dmat_c[triu].mean() if len(triu[0]) > 0 else 0.0
        for c1, c2 in combinations(class_names, 2):
            inter_e[(c1,c2)] = cdist(cdata[c1], cdata[c2], "euclidean").mean()
            inter_c[(c1,c2)] = cdist(cdata[c1], cdata[c2], "cosine").mean()
        return intra_e, intra_c, inter_e, inter_c

    intra_euc,   intra_cos,   inter_euc,   inter_cos   = _euc_cos(class_data,   class_means)
    intra_euc_r, intra_cos_r, inter_euc_r, inter_cos_r = _euc_cos(class_data_r, class_means_r)

    pooled_cov = np.cov(emb_r, rowvar=False) + np.eye(n_components) * 1e-6
    try:    cov_inv = np.linalg.inv(pooled_cov)
    except: cov_inv = np.linalg.pinv(pooled_cov)

    intra_mah, inter_mah = {}, {}
    for c in class_names:
        d = class_data_r[c]
        intra_mah[c] = np.mean([mahalanobis(d[i], class_means_r[c], cov_inv) for i in range(len(d))])
    for c1, c2 in combinations(class_names, 2):
        inter_mah[(c1,c2)] = mahalanobis(class_means_r[c1], class_means_r[c2], cov_inv)

    report = ["="*85, f"DISTANCE ANALYSIS — {tag}", f"Model: {MODEL_NAME}",
              f"PCA-{n_components} variance explained: {var_explained:.1%}", "="*85]

    for space_label, intra_e, intra_c, inter_e, inter_c, show_mah in [
        (f"FULL {emb.shape[1]}-d SPACE",  intra_euc,   intra_cos,   inter_euc,   inter_cos,   False),
        (f"PCA-{n_components} SPACE",     intra_euc_r, intra_cos_r, inter_euc_r, inter_cos_r, True),
    ]:
        report.append(f"\n  ── {space_label} ──")
        report.append(f"  INTRA-CLASS:")
        hdr = f"  {'Class':<25} {'Avg Euclidean':>15} {'Avg Cosine':>12}"
        if show_mah: hdr += f" {'Mahalanobis':>13}"
        hdr += f" {'N':>6}"
        report.append(hdr); report.append(f"  {'-'*(len(hdr)-2)}")
        for c in class_names:
            row = f"  {c:<25} {intra_e[c]:>15.4f} {intra_c[c]:>12.4f}"
            if show_mah: row += f" {intra_mah[c]:>13.4f}"
            row += f" {class_data[c].shape[0]:>6}"
            report.append(row)

        report.append(f"\n  INTER-CLASS:")
        hdr2 = f"  {'Pair':<40} {'Avg Euclidean':>15} {'Avg Cosine':>12}"
        if show_mah: hdr2 += f" {'Mahalanobis':>13}"
        report.append(hdr2); report.append(f"  {'-'*(len(hdr2)-2)}")
        for c1, c2 in combinations(class_names, 2):
            pair = f"{c1} vs {c2}"
            row  = f"  {pair:<40} {inter_e[(c1,c2)]:>15.4f} {inter_c[(c1,c2)]:>12.4f}"
            if show_mah: row += f" {inter_mah[(c1,c2)]:>13.4f}"
            report.append(row)

        report.append(f"\n  SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine")
        if show_mah: report[-1] += " & Mahalanobis"
        hdr3 = f"  {'Pair':<40} {'Euc ratio':>10} {'Cos ratio':>10}"
        if show_mah: hdr3 += f" {'Mah ratio':>10}"
        report.append(hdr3); report.append(f"  {'-'*(len(hdr3)-2)}")
        for c1, c2 in combinations(class_names, 2):
            avg_ie = np.mean([intra_e[c1], intra_e[c2]])
            avg_ic = np.mean([intra_c[c1], intra_c[c2]])
            re     = inter_e[(c1,c2)] / avg_ie if avg_ie > 0 else float("inf")
            rc     = inter_c[(c1,c2)] / avg_ic if avg_ic > 0 else float("inf")
            row    = f"  {f'{c1} vs {c2}':<40} {re:>10.4f} {rc:>10.4f}"
            if show_mah:
                avg_im = np.mean([intra_mah[c1], intra_mah[c2]])
                row   += f" {inter_mah[(c1,c2)] / avg_im if avg_im > 0 else float('inf'):>10.4f}"
            report.append(row)

    report.append(f"\n{'='*85}")
    txt = "\n".join(report); print(txt)
    fname = f"distance_analysis_{tag.lower().replace(' ','_')}.txt"
    with open(os.path.join(results_dir, fname), "w", encoding="utf-8") as f: f.write(txt)

    short = [c.replace("Theory of Computation","ToC").replace("Information Security","InfoSec")
               .replace("Computer Science","CS").replace("No-Hate Speech","No-Hate")
               .replace("Hate Speech","Hate") for c in class_names]
    n_cls = len(class_names)
    for metric_name, intra_d, inter_d, key in [
        (f"Euclidean (full {emb.shape[1]}-d)", intra_euc,   inter_euc,   "full_euclidean"),
        (f"Cosine (full {emb.shape[1]}-d)",    intra_cos,   inter_cos,   "full_cosine"),
        (f"Euclidean (PCA-{n_components})",    intra_euc_r, inter_euc_r, "pca_euclidean"),
        (f"Cosine (PCA-{n_components})",       intra_cos_r, inter_cos_r, "pca_cosine"),
        (f"Mahalanobis (PCA-{n_components})",  intra_mah,   inter_mah,   "pca_mahalanobis"),
    ]:
        mat = np.zeros((n_cls, n_cls))
        for i, ci in enumerate(class_names):
            mat[i,i] = intra_d[ci]
            for j, cj in enumerate(class_names):
                if i < j: mat[i,j] = mat[j,i] = inter_d[(ci,cj)]
        fig, ax = plt.subplots(figsize=(9,7))
        im = ax.imshow(mat, cmap="YlOrRd", interpolation="nearest")
        plt.colorbar(im, ax=ax, shrink=0.8)
        for i in range(n_cls):
            for j in range(n_cls):
                color = "white" if mat[i,j] > mat.max()*0.65 else "black"
                ax.text(j, i, f"{mat[i,j]:.3f}\n{'(intra)' if i==j else '(inter)'}",
                        ha="center", va="center", fontsize=9, fontweight="bold", color=color)
        ax.set_xticks(range(n_cls)); ax.set_xticklabels(short, fontsize=10, rotation=30, ha="right")
        ax.set_yticks(range(n_cls)); ax.set_yticklabels(short, fontsize=10)
        ax.set_title(f"{metric_name} — {tag}\nBERT-large-uncased", fontsize=12, fontweight="bold")
        plt.tight_layout()
        plt.savefig(os.path.join(results_dir, f"dist_{key}_{tag.lower().replace(' ','_')}.png"), dpi=150, bbox_inches="tight")
        plt.show(); plt.close()


print("\n─── Distance Analysis: all 6 categories ───")
compute_distances(all_embeddings, all_labels, "All Categories", DIR_DIST)
for c1, c2 in PAIRS:
    mask = np.isin(all_labels, [c1, c2])
    print(f"\n─── Distance: {c1} vs {c2} ───")
    compute_distances(all_embeddings[mask], all_labels[mask], f"{c1} vs {c2}", DIR_DIST)
# Out:
# ─── Distance Analysis: all 6 categories ───
#   PCA-50 variance explained: 77.2%
# =====================================================================================
# DISTANCE ANALYSIS — All Categories
# Model: bert-large-uncased
# PCA-50 variance explained: 77.2%
# =====================================================================================
#
#   ── FULL 1024-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Shakespeare                        7.8092       0.2751    100
#   Computer Science                   7.2781       0.2502    100
#   Information Security               6.9563       0.2214    100
#   Theory of Computation              6.8440       0.2174    100
#   Hate Speech                        4.8097       0.1427    100
#   No-Hate Speech                     5.0788       0.1549    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Shakespeare vs Computer Science                   9.2054       0.3906
#   Shakespeare vs Information Security               9.2498       0.3883
#   Shakespeare vs Theory of Computation              9.4052       0.4012
#   Shakespeare vs Hate Speech                        7.9958       0.3260
#   Shakespeare vs No-Hate Speech                     8.0490       0.3278
#   Computer Science vs Information Security          7.5716       0.2659
#   Computer Science vs Theory of Computation          7.8994       0.2901
#   Computer Science vs Hate Speech                   8.3045       0.3616
#   Computer Science vs No-Hate Speech                8.3546       0.3623
#   Information Security vs Theory of Computation          8.5121       0.3302
#   Information Security vs Hate Speech               8.1939       0.3443
#   Information Security vs No-Hate Speech            8.2542       0.3461
#   Theory of Computation vs Hate Speech              8.6839       0.3876
#   Theory of Computation vs No-Hate Speech           8.7622       0.3909
#   Hate Speech vs No-Hate Speech                     4.9768       0.1506
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Shakespeare vs Computer Science              1.2203     1.4871
#   Shakespeare vs Information Security          1.2529     1.5641
#   Shakespeare vs Theory of Computation         1.2837     1.6293
#   Shakespeare vs Hate Speech                   1.2673     1.5607
#   Shakespeare vs No-Hate Speech                1.2491     1.5247
#   Computer Science vs Information Security     1.0638     1.1277
#   Computer Science vs Theory of Computation     1.1187     1.2411
#   Computer Science vs Hate Speech              1.3740     1.8408
#   Computer Science vs No-Hate Speech           1.3522     1.7890
#   Information Security vs Theory of Computation     1.2336     1.5050
#   Information Security vs Hate Speech          1.3928     1.8911
#   Information Security vs No-Hate Speech       1.3717     1.8394
#   Theory of Computation vs Hate Speech         1.4903     2.1529
#   Theory of Computation vs No-Hate Speech      1.4698     2.0999
#   Hate Speech vs No-Hate Speech                1.0066     1.0119
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Shakespeare                        6.0113       0.5879        8.1995    100
#   Computer Science                   6.1280       0.7230        7.5268    100
#   Information Security               5.7202       0.6264        7.2286    100
#   Theory of Computation              5.6986       0.5395        6.8836    100
#   Hate Speech                        3.6318       0.4005        4.6082    100
#   No-Hate Speech                     3.8139       0.4255        4.9216    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Shakespeare vs Computer Science                   8.0622       1.1504        3.0993
#   Shakespeare vs Information Security               8.1041       1.1580        3.2211
#   Shakespeare vs Theory of Computation              8.3213       1.1269        3.2633
#   Shakespeare vs Hate Speech                        6.8430       0.9899        2.9518
#   Shakespeare vs No-Hate Speech                     6.8591       0.9846        2.9710
#   Computer Science vs Information Security          6.4701       0.8018        2.6604
#   Computer Science vs Theory of Computation          6.8912       0.8324        2.7969
#   Computer Science vs Hate Speech                   7.5115       1.3203        2.7486
#   Computer Science vs No-Hate Speech                7.5249       1.3104        2.7351
#   Information Security vs Theory of Computation          7.5853       0.9998        3.1167
#   Information Security vs Hate Speech               7.3782       1.2641        2.8437
#   Information Security vs No-Hate Speech            7.4036       1.2590        2.8761
#   Theory of Computation vs Hate Speech              7.9575       1.3401        2.8843
#   Theory of Computation vs No-Hate Speech           8.0035       1.3420        2.9090
#   Hate Speech vs No-Hate Speech                     3.7628       0.4213        1.3218
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Shakespeare vs Computer Science              1.3283     1.7551     0.3942
#   Shakespeare vs Information Security          1.3816     1.9074     0.4176
#   Shakespeare vs Theory of Computation         1.4212     1.9990     0.4327
#   Shakespeare vs Hate Speech                   1.4193     2.0032     0.4609
#   Shakespeare vs No-Hate Speech                1.3962     1.9432     0.4529
#   Computer Science vs Information Security     1.0922     1.1884     0.3606
#   Computer Science vs Theory of Computation     1.1654     1.3186     0.3882
#   Computer Science vs Hate Speech              1.5393     2.3504     0.4530
#   Computer Science vs No-Hate Speech           1.5138     2.2821     0.4394
#   Information Security vs Theory of Computation     1.3286     1.7151     0.4417
#   Information Security vs Hate Speech          1.5779     2.4622     0.4805
#   Information Security vs No-Hate Speech       1.5531     2.3939     0.4734
#   Theory of Computation vs Hate Speech         1.7057     2.8513     0.5020
#   Theory of Computation vs No-Hate Speech      1.6827     2.7813     0.4928
#   Hate Speech vs No-Hate Speech                1.0107     1.0201     0.2774
#
# =====================================================================================
#
# ─── Distance: Computer Science vs Shakespeare ───
#   PCA-50 variance explained: 80.5%
# =====================================================================================
# DISTANCE ANALYSIS — Computer Science vs Shakespeare
# Model: bert-large-uncased
# PCA-50 variance explained: 80.5%
# =====================================================================================
#
#   ── FULL 1024-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Shakespeare                        7.8092       0.2751    100
#   Computer Science                   7.2781       0.2502    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Shakespeare vs Computer Science                   9.2054       0.3906
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Shakespeare vs Computer Science              1.2203     1.4871
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Shakespeare                        6.6786       0.7494        7.2246    100
#   Computer Science                   6.3137       0.7465        6.4503    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Shakespeare vs Computer Science                   8.3914       1.2586        1.9737
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Shakespeare vs Computer Science              1.2918     1.6826     0.2887
#
# =====================================================================================
#
# ─── Distance: Theory of Computation vs Information Security ───
#   PCA-50 variance explained: 85.3%
# =====================================================================================
# DISTANCE ANALYSIS — Theory of Computation vs Information Security
# Model: bert-large-uncased
# PCA-50 variance explained: 85.3%
# =====================================================================================
#
#   ── FULL 1024-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Information Security               6.9563       0.2214    100
#   Theory of Computation              6.8440       0.2174    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Information Security vs Theory of Computation          8.5121       0.3302
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Information Security vs Theory of Computation     1.2336     1.5050
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Information Security               6.2166       0.7644        7.1313    100
#   Theory of Computation              6.1726       0.7609        6.6581    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Information Security vs Theory of Computation          7.9606       1.2444        1.9358
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Information Security vs Theory of Computation     1.2851     1.6317     0.2808
#
# =====================================================================================
#
# ─── Distance: Hate Speech vs No-Hate Speech ───
#   PCA-50 variance explained: 81.5%
# =====================================================================================
# DISTANCE ANALYSIS — Hate Speech vs No-Hate Speech
# Model: bert-large-uncased
# PCA-50 variance explained: 81.5%
# =====================================================================================
#
#   ── FULL 1024-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Hate Speech                        4.8097       0.1427    100
#   No-Hate Speech                     5.0788       0.1549    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                     4.9768       0.1506
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                1.0066     1.0119
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Hate Speech                        4.2787       0.9936        6.5432    100
#   No-Hate Speech                     4.5723       0.9974        7.1320    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                     4.4648       1.0128        1.3467
#
#   SEPARABILITY RATIO (inter / avg intra) — Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                1.0089     1.0174     0.1970
#
# =====================================================================================

# %%
def compute_kl_divergence(emb, labs, tag, results_dir):
    class_names = [c for c in ALL_CATS if c in set(labs)]
    n_bins, eps = 50, 1e-10
    class_data  = {c: emb[labs == c] for c in class_names}
    g_min, g_max = emb.min(axis=0), emb.max(axis=0)

    class_dists = {}
    for c in class_names:
        dists = []
        for d in range(emb.shape[1]):
            vals = class_data[c][:, d]; lo, hi = g_min[d], g_max[d]
            if hi - lo < 1e-12:
                hist = np.ones(n_bins) / n_bins
            else:
                hist, _ = np.histogram(vals, bins=n_bins, range=(lo, hi))
                hist = hist.astype(np.float64) + eps; hist /= hist.sum()
            dists.append(hist)
        class_dists[c] = np.array(dists)

    n_cls = len(class_names)
    kl_matrix = np.zeros((n_cls, n_cls))
    report = ["="*70, f"KL DIVERGENCE — {tag}", f"Model: {MODEL_NAME}", "="*70]
    report.append(f"\n  {'P \\ Q':<25} " + " ".join(f"{c:>15}" for c in class_names))
    report.append(f"  {'-'*(25 + 16*n_cls)}")
    for i, ci in enumerate(class_names):
        row = []
        for j, cj in enumerate(class_names):
            if i == j:
                kl_matrix[i,j] = 0.0; row.append(f"{'0.0000':>15}")
            else:
                kl = np.mean([np.sum(rel_entr(class_dists[ci][k], class_dists[cj][k]))
                              for k in range(emb.shape[1])])
                kl_matrix[i,j] = kl; row.append(f"{kl:>15.4f}")
        report.append(f"  {ci:<25} " + " ".join(row))

    report.append(f"\n{'='*70}")
    txt = "\n".join(report); print(txt)
    fname = f"kl_divergence_{tag.lower().replace(' ','_')}.txt"
    with open(os.path.join(results_dir, fname), "w", encoding="utf-8") as f: f.write(txt)

    short = [c.replace("Theory of Computation","ToC").replace("Information Security","InfoSec")
               .replace("Computer Science","CS").replace("No-Hate Speech","No-Hate")
               .replace("Hate Speech","Hate") for c in class_names]
    fig, ax = plt.subplots(figsize=(max(7, n_cls*1.4), max(6, n_cls*1.2)))
    im = ax.imshow(kl_matrix, cmap="Blues", interpolation="nearest")
    plt.colorbar(im, ax=ax, shrink=0.8, label="KL Divergence (nats)")
    for i in range(n_cls):
        for j in range(n_cls):
            color = "white" if kl_matrix[i,j] > kl_matrix.max()*0.65 else "black"
            ax.text(j, i, f"{kl_matrix[i,j]:.3f}", ha="center", va="center",
                    fontsize=10, fontweight="bold", color=color)
    ax.set_xticks(range(n_cls)); ax.set_xticklabels(short, fontsize=10, rotation=30, ha="right")
    ax.set_yticks(range(n_cls)); ax.set_yticklabels(short, fontsize=10)
    ax.set_xlabel("Q (reference)", fontsize=11); ax.set_ylabel("P (source)", fontsize=11)
    ax.set_title(f"KL Divergence — {tag}\nBERT-large-uncased  |  KL(P‖Q) avg over neurons",
                 fontsize=12, fontweight="bold")
    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, f"kl_divergence_{tag.lower().replace(' ','_')}.png"),
                dpi=150, bbox_inches="tight")
    plt.show(); plt.close()


print("\n─── KL Divergence: all 6 categories ───")
compute_kl_divergence(all_embeddings, all_labels, "All Categories", DIR_KL)
for c1, c2 in PAIRS:
    mask = np.isin(all_labels, [c1, c2])
    print(f"\n─── KL Divergence: {c1} vs {c2} ───")
    compute_kl_divergence(all_embeddings[mask], all_labels[mask], f"{c1} vs {c2}", DIR_KL)
# Out:
# ─── KL Divergence: all 6 categories ───
# ======================================================================
# KL DIVERGENCE — All Categories
# Model: bert-large-uncased
# ======================================================================
#
#   P \ Q                         Shakespeare Computer Science Information Security Theory of Computation     Hate Speech  No-Hate Speech
#   -------------------------------------------------------------------------------------------------------------------------
#   Shakespeare                        0.0000          5.0062          5.5762          5.9935          7.2825          6.7554
#   Computer Science                   4.5944          0.0000          2.8221          3.5779          7.8906          7.4595
#   Information Security               4.7259          2.5006          0.0000          4.6215          7.6775          7.2404
#   Theory of Computation              4.9469          3.0504          4.3887          0.0000          8.5318          8.0675
#   Hate Speech                        3.0174          4.0154          4.2087          5.2544          0.0000          1.1796
#   No-Hate Speech                     3.0790          4.0916          4.2859          5.2908          1.5622          0.0000
#
# ======================================================================
#
# ─── KL Divergence: Computer Science vs Shakespeare ───
# ======================================================================
# KL DIVERGENCE — Computer Science vs Shakespeare
# Model: bert-large-uncased
# ======================================================================
#
#   P \ Q                         Shakespeare Computer Science
#   ---------------------------------------------------------
#   Shakespeare                        0.0000          5.2713
#   Computer Science                   4.8297          0.0000
#
# ======================================================================
#
# ─── KL Divergence: Theory of Computation vs Information Security ───
# ======================================================================
# KL DIVERGENCE — Theory of Computation vs Information Security
# Model: bert-large-uncased
# ======================================================================
#
#   P \ Q                     Information Security Theory of Computation
#   ---------------------------------------------------------
#   Information Security               0.0000          5.4423
#   Theory of Computation              5.1996          0.0000
#
# ======================================================================
#
# ─── KL Divergence: Hate Speech vs No-Hate Speech ───
# ======================================================================
# KL DIVERGENCE — Hate Speech vs No-Hate Speech
# Model: bert-large-uncased
# ======================================================================
#
#   P \ Q                         Hate Speech  No-Hate Speech
#   ---------------------------------------------------------
#   Hate Speech                        0.0000          2.5385
#   No-Hate Speech                     2.9846          0.0000
#
# ======================================================================

# %%
def compute_silhouette(emb, labs, tag, results_dir, n_pca=50):
    pca_red = PCA(n_components=min(n_pca, emb.shape[0]-1, emb.shape[1]))
    emb_r   = pca_red.fit_transform(emb)
    score   = silhouette_score(emb_r, labs)
    samples = silhouette_samples(emb_r, labs)

    class_names = [c for c in ALL_CATS if c in set(labs)]
    report = ["="*60, f"SILHOUETTE SCORES — {tag}",
              f"Model: {MODEL_NAME}  |  PCA reduced to {emb_r.shape[1]} dims", "="*60,
              f"\n  Overall silhouette score: {score:.4f}",
              f"  (range -1 to +1; higher = better separated)\n",
              f"  {'Class':<25} {'Mean silhouette':>16} {'N':>6}", f"  {'-'*49}"]
    for c in class_names:
        idx = labs == c
        report.append(f"  {c:<25} {samples[idx].mean():>16.4f} {idx.sum():>6}")
    report.append(f"\n{'='*60}")
    txt = "\n".join(report); print(txt)
    fname = f"silhouette_{tag.lower().replace(' ','_')}.txt"
    with open(os.path.join(results_dir, fname), "w", encoding="utf-8") as f: f.write(txt)

    class_scores = [samples[labs == c].mean() for c in class_names]
    short = [c.replace("Theory of Computation","ToC").replace("Information Security","InfoSec")
               .replace("Computer Science","CS").replace("No-Hate Speech","No-Hate")
               .replace("Hate Speech","Hate") for c in class_names]
    fig, ax = plt.subplots(figsize=(max(7, len(class_names)*1.3), 5))
    bars = ax.bar(short, class_scores, color=[COLORS[c] for c in class_names],
                  edgecolor="white", linewidth=0.8)
    ax.axhline(score, color="black", linestyle="--", linewidth=1.2, label=f"Overall: {score:.3f}")
    ax.axhline(0, color="grey", linestyle=":", linewidth=0.8)
    for bar, val in zip(bars, class_scores):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
                f"{val:.3f}", ha="center", va="bottom", fontsize=10, fontweight="bold")
    ax.set_ylabel("Mean Silhouette Score", fontsize=11)
    ax.set_title(f"Silhouette Scores — {tag}\nBERT-large-uncased (PCA-{emb_r.shape[1]})",
                 fontsize=12, fontweight="bold")
    ax.legend(fontsize=10)
    ax.set_ylim(min(class_scores) - 0.05, max(class_scores) + 0.08)
    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, f"silhouette_{tag.lower().replace(' ','_')}.png"),
                dpi=150, bbox_inches="tight")
    plt.show(); plt.close()
    return score


print("\n─── Silhouette: all 6 categories ───")
compute_silhouette(all_embeddings, all_labels, "All Categories", DIR_SIL)
for c1, c2 in PAIRS:
    mask = np.isin(all_labels, [c1, c2])
    print(f"\n─── Silhouette: {c1} vs {c2} ───")
    compute_silhouette(all_embeddings[mask], all_labels[mask], f"{c1} vs {c2}", DIR_SIL)
# Out:
# ─── Silhouette: all 6 categories ───
# ============================================================
# SILHOUETTE SCORES — All Categories
# Model: bert-large-uncased  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.0725
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Shakespeare                         0.1183    100
#   Computer Science                    0.0178    100
#   Information Security                0.1120    100
#   Theory of Computation               0.1652    100
#   Hate Speech                         0.0355    100
#   No-Hate Speech                     -0.0137    100
#
# ============================================================
#
# ─── Silhouette: Computer Science vs Shakespeare ───
# ============================================================
# SILHOUETTE SCORES — Computer Science vs Shakespeare
# Model: bert-large-uncased  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.2263
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Shakespeare                         0.2064    100
#   Computer Science                    0.2461    100
#
# ============================================================
#
# ─── Silhouette: Theory of Computation vs Information Security ───
# ============================================================
# SILHOUETTE SCORES — Theory of Computation vs Information Security
# Model: bert-large-uncased  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.2182
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Information Security                0.2165    100
#   Theory of Computation               0.2200    100
#
# ============================================================
#
# ─── Silhouette: Hate Speech vs No-Hate Speech ───
# ============================================================
# SILHOUETTE SCORES — Hate Speech vs No-Hate Speech
# Model: bert-large-uncased  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.0092
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Hate Speech                         0.0427    100
#   No-Hate Speech                     -0.0243    100
#
# ============================================================

# %%
def pca_plot(emb, labs, cats, title, fname_base, results_dir):
    mask    = np.isin(labs, cats)
    emb_sub = emb[mask]; lab_sub = labs[mask]

    pca2 = PCA(n_components=2); X2 = pca2.fit_transform(emb_sub); evr2 = pca2.explained_variance_ratio_
    fig, ax = plt.subplots(figsize=(10,8))
    for cat in cats:
        idx = lab_sub == cat
        ax.scatter(X2[idx,0], X2[idx,1], c=COLORS[cat], label=cat,
                   alpha=0.75, edgecolors="w", linewidths=0.5, s=60)
    ax.set_xlabel(f"PC 1  ({evr2[0]:.1%})", fontsize=12)
    ax.set_ylabel(f"PC 2  ({evr2[1]:.1%})", fontsize=12)
    ax.set_title(f"BERT-large-uncased — 2D PCA\n{title}", fontsize=14, fontweight="bold")
    ax.legend(fontsize=10); ax.grid(True, linestyle="--", alpha=0.4)
    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, f"{fname_base}_2d.png"), dpi=150, bbox_inches="tight")
    plt.show(); plt.close()

    pca3 = PCA(n_components=3); X3 = pca3.fit_transform(emb_sub); evr3 = pca3.explained_variance_ratio_
    fig = plt.figure(figsize=(12,10)); ax = fig.add_subplot(111, projection="3d")
    for cat in cats:
        idx = lab_sub == cat
        ax.scatter(X3[idx,0], X3[idx,1], X3[idx,2], c=COLORS[cat], label=cat,
                   alpha=0.75, edgecolors="w", linewidths=0.5, s=60)
    ax.set_xlabel(f"PC 1  ({evr3[0]:.1%})", fontsize=10)
    ax.set_ylabel(f"PC 2  ({evr3[1]:.1%})", fontsize=10)
    ax.set_zlabel(f"PC 3  ({evr3[2]:.1%})", fontsize=10)
    ax.set_title(f"BERT-large-uncased — 3D PCA\n{title}", fontsize=14, fontweight="bold")
    ax.legend(fontsize=10)
    plt.tight_layout()
    plt.savefig(os.path.join(results_dir, f"{fname_base}_3d.png"), dpi=150, bbox_inches="tight")
    plt.show(); plt.close()


print("\n─── PCA: all 6 categories ───")
pca_plot(all_embeddings, all_labels, ALL_CATS, "All 6 Categories", "pca_all", DIR_PCA)

pair_meta = [
    (["Computer Science", "Shakespeare"],               "CS vs Shakespeare",          "pca_cs_shakespeare"),
    (["Theory of Computation", "Information Security"], "ToC vs Information Security", "pca_toc_infosec"),
    (["Hate Speech", "No-Hate Speech"],                 "Hate vs No-Hate Speech",     "pca_hate"),
]
for cats, title, fname in pair_meta:
    print(f"\n  {title}")
    pca_plot(all_embeddings, all_labels, cats, title, fname, DIR_PCA)
# Out:
# ─── PCA: all 6 categories ───
#
#   CS vs Shakespeare
#
#   ToC vs Information Security
#
#   Hate vs No-Hate Speech

# %%
def find_overlapping_sentences(emb, labs, sents, c1, c2, top_k=5, results_dir=None, n_pca=50):
    idx1 = np.where(labs == c1)[0]; idx2 = np.where(labs == c2)[0]
    dmat_full = cdist(emb[idx1], emb[idx2], "euclidean")

    n_components = min(n_pca, emb.shape[0]-1, emb.shape[1])
    pca50        = PCA(n_components=n_components)
    emb_r        = pca50.fit_transform(emb)
    var_explained = pca50.explained_variance_ratio_.sum()
    dmat_pca = cdist(emb_r[idx1], emb_r[idx2], "euclidean")

    report = ["="*80, f"MOST OVERLAPPING SENTENCE PAIRS  —  {c1}  vs  {c2}", "="*80]
    for space_label, dmat in [
        (f"Full {emb.shape[1]}-d Euclidean", dmat_full),
        (f"PCA-{n_components} Euclidean  (variance explained: {var_explained:.1%})", dmat_pca),
    ]:
        report.append(f"\n  ── {space_label} ──")
        top = np.argsort(dmat.flatten())[:top_k]
        for rank, flat_idx in enumerate(top, 1):
            i, j = np.unravel_index(flat_idx, dmat.shape)
            report.append(f"\n  Rank {rank}  |  distance = {dmat[i,j]:.4f}")
            report.append(f"  [{c1}]  {sents[idx1[i]]}")
            report.append(f"  [{c2}]  {sents[idx2[j]]}")

    txt = "\n".join(report); print(txt)
    if results_dir:
        safe  = f"{c1}_{c2}".lower().replace(" ","_")
        fname = os.path.join(results_dir, f"overlap_{safe}.txt")
        with open(fname, "w", encoding="utf-8") as f: f.write(txt)
        print(f"\n  Saved {fname}")


print("\n─── Overlapping sentences ───")
for c1, c2 in PAIRS:
    find_overlapping_sentences(all_embeddings, all_labels, all_sentences,
                               c1, c2, top_k=5, results_dir=DIR_OVER)
# Out:
# ─── Overlapping sentences ───
# ================================================================================
# MOST OVERLAPPING SENTENCE PAIRS  —  Computer Science  vs  Shakespeare
# ================================================================================
#
#   ── Full 1024-d Euclidean ──
#
#   Rank 1  |  distance = 6.3419
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  The empty vessel makes the loudest sound.
#
#   Rank 2  |  distance = 6.4196
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  The devil can cite Scripture for his purpose.
#
#   Rank 3  |  distance = 6.4457
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  When sorrows come, they come not single spies, but in battalions.
#
#   Rank 4  |  distance = 6.4921
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  Pleasure and action make the hours seem short.
#
#   Rank 5  |  distance = 6.6329
#   [Computer Science]  Computer vision enables machines to interpret images.
#   [Shakespeare]  The devil can cite Scripture for his purpose.
#
#   ── PCA-50 Euclidean  (variance explained: 77.2%) ──
#
#   Rank 1  |  distance = 4.4546
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  The empty vessel makes the loudest sound.
#
#   Rank 2  |  distance = 5.0335
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  Pleasure and action make the hours seem short.
#
#   Rank 3  |  distance = 5.0450
#   [Computer Science]  Overfitting occurs when a model learns noise instead of patterns.
#   [Shakespeare]  The devil can cite Scripture for his purpose.
#
#   Rank 4  |  distance = 5.0744
#   [Computer Science]  Computer vision enables machines to interpret images.
#   [Shakespeare]  The devil can cite Scripture for his purpose.
#
#   Rank 5  |  distance = 5.1146
#   [Computer Science]  A confusion matrix summarizes prediction results.
#   [Shakespeare]  The empty vessel makes the loudest sound.
#
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_bert_large_sentences/overlap/overlap_computer_science_shakespeare.txt
# ================================================================================
# MOST OVERLAPPING SENTENCE PAIRS  —  Theory of Computation  vs  Information Security
# ================================================================================
#
#   ── Full 1024-d Euclidean ──
#
#   Rank 1  |  distance = 4.9580
#   [Theory of Computation]  Time complexity measures execution steps.
#   [Information Security]  Timing attacks analyze execution duration.
#
#   Rank 2  |  distance = 5.3714
#   [Theory of Computation]  Nondeterministic finite automata (NFA) can have multiple transitions for a symbol.
#   [Information Security]  Hash functions generate fixed-length outputs from arbitrary input.
#
#   Rank 3  |  distance = 5.5776
#   [Theory of Computation]  Encoding allows machines to process other machines.
#   [Information Security]  Tokenization replaces sensitive data with tokens.
#
#   Rank 4  |  distance = 5.5904
#   [Theory of Computation]  Time complexity measures execution steps.
#   [Information Security]  Static analysis examines code without execution.
#
#   Rank 5  |  distance = 5.5964
#   [Theory of Computation]  Deterministic finite automata (DFA) have exactly one transition per input symbol.
#   [Information Security]  Hash functions generate fixed-length outputs from arbitrary input.
#
#   ── PCA-50 Euclidean  (variance explained: 77.2%) ──
#
#   Rank 1  |  distance = 3.6715
#   [Theory of Computation]  Time complexity measures execution steps.
#   [Information Security]  Timing attacks analyze execution duration.
#
#   Rank 2  |  distance = 4.0335
#   [Theory of Computation]  Nondeterministic finite automata (NFA) can have multiple transitions for a symbol.
#   [Information Security]  Hash functions generate fixed-length outputs from arbitrary input.
#
#   Rank 3  |  distance = 4.0721
#   [Theory of Computation]  A Turing machine consists of a tape, head, and control unit.
#   [Information Security]  A virus requires a host program to propagate.
#
#   Rank 4  |  distance = 4.1638
#   [Theory of Computation]  Encoding allows machines to process other machines.
#   [Information Security]  Tokenization replaces sensitive data with tokens.
#
#   Rank 5  |  distance = 4.2416
#   [Theory of Computation]  Time complexity measures execution steps.
#   [Information Security]  Static analysis examines code without execution.
#
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_bert_large_sentences/overlap/overlap_theory_of_computation_information_security.txt
# ================================================================================
# MOST OVERLAPPING SENTENCE PAIRS  —  Hate Speech  vs  No-Hate Speech
# ================================================================================
#
#   ── Full 1024-d Euclidean ──
#
#   Rank 1  |  distance = 2.6430
#   [Hate Speech]  And would AMERICA be shocked ? The DEMOCRAPS are shady people looking out for THEMSELVES #TRUMP2020 #THEGLOVESROFF #DRAINTHESWAMP https://t.co/KoUbh1TZXq
#   [No-Hate Speech]  Time to move on and focus on the debt, the tax fraud, the lies and follow the money. Who does Trump owe $420MM to? Why won’t Trump condemn Putin ever?[NEWLINE]#TrumpHasNoPlan #TrumpLies #TrumpTaxFraud #TrumpVirusCatastrophe #DumpTrump2020 #VOTE #BidenHarris2020 https://t.co/V3lSBMI0HE
#
#   Rank 2  |  distance = 2.6437
#   [Hate Speech]  #TrumpVirusDeathToll211K [NEWLINE][NEWLINE]#VirtuallyNobody until the #MalignantNarcisisst actually gets it.[NEWLINE][NEWLINE]No #Empathy #Compassion #Kindness #Understanding [NEWLINE][NEWLINE]I’m voting #November3rd for #Decency #BidenHarris2020 https://t.co/jtqljF2HY2
#   [No-Hate Speech]  It’s only going to get worse[NEWLINE]Pay attention Catholics [NEWLINE][NEWLINE]#RememberinNovember [NEWLINE]#FoxAndFriends #MAGA #Ccot #ACB [NEWLINE]#Trump2020 #KAG #KAG2020 [NEWLINE]#SaturdayMorning #SaturdayThoughts [NEWLINE]#COVID19[NEWLINE][NEWLINE] https://t.co/u1PH7iezfC
#
#   Rank 3  |  distance = 2.8001
#   [Hate Speech]  Facebook approves of Nazi-ism but does not condone love.[NEWLINE][NEWLINE]Holy crap I’m angry about this![NEWLINE][NEWLINE]ߤ솪ck Facebookߤ웎EWLINE][NEWLINE]#Biden2020 [NEWLINE]#ProudBoys https://t.co/S7pBKItrkD
#   [No-Hate Speech]  It’s only going to get worse[NEWLINE]Pay attention Catholics [NEWLINE][NEWLINE]#RememberinNovember [NEWLINE]#FoxAndFriends #MAGA #Ccot #ACB [NEWLINE]#Trump2020 #KAG #KAG2020 [NEWLINE]#SaturdayMorning #SaturdayThoughts [NEWLINE]#COVID19[NEWLINE][NEWLINE] https://t.co/u1PH7iezfC
#
#   Rank 4  |  distance = 2.8361
#   [Hate Speech]  Ok so whose job was it to vet the #Republican candidate for #potus Because that was the most epic fuck up in world history! #TrumpIsANationalSecurityThreat [NEWLINE]#TrumpIsNotABillionaire #TrumpTaxCheat #VoteBlue2020 #BidenHarrisToSaveAmerica
#   [No-Hate Speech]  Time to move on and focus on the debt, the tax fraud, the lies and follow the money. Who does Trump owe $420MM to? Why won’t Trump condemn Putin ever?[NEWLINE]#TrumpHasNoPlan #TrumpLies #TrumpTaxFraud #TrumpVirusCatastrophe #DumpTrump2020 #VOTE #BidenHarris2020 https://t.co/V3lSBMI0HE
#
#   Rank 5  |  distance = 2.8624
#   [Hate Speech]  As Election Day nears, the greater his need for a war. He’ll do everything possible to take our minds off of voting. [NEWLINE][NEWLINE]However, the mail in votes will heavily favor a Biden win. [NEWLINE][NEWLINE]There is no way tRump can legally win this election. His crime family &amp; ProudBoys is all he has. https://t.co/P3KM4DhBfJ
#   [No-Hate Speech]  I am lovin’ all these speeches of TRUTH. Joe, Barack, Kamala, THE GOOD GUYS. The JEDI KNIGHTS! [NEWLINE][NEWLINE]Defeat the TWITTER TROLL TRUMP occupying the White House and save us all from his toxic bile. Block him with a vote for Biden-Harris. https://t.co/jAWgH8z0l7
#
#   ── PCA-50 Euclidean  (variance explained: 77.2%) ──
#
#   Rank 1  |  distance = 1.5075
#   [Hate Speech]  @CNN Another event to keep spreading the #coronavirus since the #GOP can't reliably wear a damn mask!!! What idiotic irresponsible clowns ߤᰟ䡰嵐 #TrumpCovid #Election2020 #GOPCorruptionOverCountry #VoteBlue2020
#   [No-Hate Speech]  #Trump2020, #BernieBros, #fakegressives &amp; their #Russian Troll friends are trying to steal #Election2020! Make a plan now to #VoteByMail, #EarlyVote or on #ElectionDay Nov 3rd for #BidenHarris2020! Together, we can #FlipTheSenate &amp; restore the soul of our #nation!
#
#   Rank 2  |  distance = 1.5412
#   [Hate Speech]  And would AMERICA be shocked ? The DEMOCRAPS are shady people looking out for THEMSELVES #TRUMP2020 #THEGLOVESROFF #DRAINTHESWAMP https://t.co/KoUbh1TZXq
#   [No-Hate Speech]  Time to move on and focus on the debt, the tax fraud, the lies and follow the money. Who does Trump owe $420MM to? Why won’t Trump condemn Putin ever?[NEWLINE]#TrumpHasNoPlan #TrumpLies #TrumpTaxFraud #TrumpVirusCatastrophe #DumpTrump2020 #VOTE #BidenHarris2020 https://t.co/V3lSBMI0HE
#
#   Rank 3  |  distance = 1.5446
#   [Hate Speech]  Hey #Ohio @realDonaldTrump can’t manage his finances, is broke and doesn’t pay as much federal income tax as any of us! You really want to re-elect this loser so he can bankrupt the country? #Biden2020 is the cure for the last 4 years of #TraitorTrump https://t.co/GPUXxskYo3
#   [No-Hate Speech]  @the_real_mathis @AOC @realDonaldTrump So, back to my original tweet, thank goodness I saw the debate the other night and know NOT to vote for that job-killing anti fracking, oil hating, Joe Biden. I was blinded by Kamala by trump made me see. And Joe is still a racist. https://t.co/3wk36XAaKv
#
#   Rank 4  |  distance = 1.5729
#   [Hate Speech]  @jsolomonReports @realDonaldTrump Nothing surprises me anymore. The demoncrats are fueled by #HollywoodPedos who are God in their eyes. Bring out the wolves @Mike_Pence @POTUS im here!ߘ尟纰ߙﰟＰ #MAGA2020
#   [No-Hate Speech]  @kayleighmcenany @realDonaldTrump Omfg....THE MOST IRRESPONSIBLE CRETINOUS SELFISH ENTITY 9N THE PLANET...IS THE PRESIDENT!!!! #BidenHarris2020 GET HIM OUUUUUUTTTTTT
#
#   Rank 5  |  distance = 1.5883
#   [Hate Speech]  Facebook approves of Nazi-ism but does not condone love.[NEWLINE][NEWLINE]Holy crap I’m angry about this![NEWLINE][NEWLINE]ߤ솪ck Facebookߤ웎EWLINE][NEWLINE]#Biden2020 [NEWLINE]#ProudBoys https://t.co/S7pBKItrkD
#   [No-Hate Speech]  It’s only going to get worse[NEWLINE]Pay attention Catholics [NEWLINE][NEWLINE]#RememberinNovember [NEWLINE]#FoxAndFriends #MAGA #Ccot #ACB [NEWLINE]#Trump2020 #KAG #KAG2020 [NEWLINE]#SaturdayMorning #SaturdayThoughts [NEWLINE]#COVID19[NEWLINE][NEWLINE] https://t.co/u1PH7iezfC
#
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_bert_large_sentences/overlap/overlap_hate_speech_no-hate_speech.txt

# %%
summary = {
    "model":         MODEL_NAME,
    "embedding_dim": int(all_embeddings.shape[1]),
    "n_sentences":   {cat: int((all_labels == cat).sum()) for cat in ALL_CATS},
}
with open(os.path.join(RESULTS_DIR, "summary.json"), "w") as f:
    json.dump(summary, f, indent=2)

print(f"\n{'='*60}")
print(f"All results saved to: {RESULTS_DIR}")
print(f"{'='*60}")
# Out:
# ============================================================
# All results saved to: /content/drive/MyDrive/Thesis/results/results_pca_bert_large_sentences
# ============================================================
