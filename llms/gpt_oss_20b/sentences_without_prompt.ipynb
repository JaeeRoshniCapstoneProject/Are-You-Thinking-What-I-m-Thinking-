# %%
# !pip install -q transformers accelerate openpyxl scikit-learn scipy matplotlib pandas
# !pip install -q huggingface_hub
# !pip install -q kernels
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/pathlib.py", line 441, in __str__
#     return self._str
#            ^^^^^^^^^
# AttributeError: 'PosixPath' object has no attribute '_str'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
# ^C

# %%
from google.colab import drive
drive.mount("/content/drive")
DRIVE_BASE = "/content/drive/MyDrive/Thesis"
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import login
login()

# %%
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"
import json
import numpy as np
import pandas as pd
import torch
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist, mahalanobis
from scipy.special import rel_entr
from itertools import combinations
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL_NAME  = "openai/gpt-oss-20b"
EXCEL_PATH    = os.path.join(DRIVE_BASE, "Sentences.xlsx")
EXCEL_PATH_CS = os.path.join(DRIVE_BASE, "comp_sci_sentences.xlsx")
EXCEL_PATH_HATE  = os.path.join(DRIVE_BASE, "Hate vs Not-Hate.xlsx")
RESULTS_DIR   = os.path.join(DRIVE_BASE, "results", "results_pca_gpt_oss_20b_sentences")

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

COLORS = {
    "Shakespeare":           "#E06C75",
    "Computer Science":      "#61AFEF",
    "Information Security":  "#98C379",
    "Theory of Computation": "#E5C07B",
    "Hate Speech":           "#C678DD",   # purple
    "No-Hate Speech":        "#56B6C2",
}
CATEGORIES = list(COLORS.keys())
# Out:
# Device: cpu

# %%
def load_sentences(excel_path, excel_path_cs):
    sentences = {}
    df1 = pd.read_excel(excel_path)
    for col in ["Shakespeare", "Computer Science"]:
        raw = df1[col].dropna().astype(str).tolist()
        sentences[col] = [s.strip() for s in raw if s.strip()]

    df2 = pd.read_excel(excel_path_cs)
    for col in ["Information Security", "Theory of Computation"]:
        raw = df2[col].dropna().astype(str).tolist()
        sentences[col] = [s.strip() for s in raw if s.strip()]

    return sentences


print("Loading sentences ...")
sentences = load_sentences(EXCEL_PATH, EXCEL_PATH_CS)
for cat, sents in sentences.items():
    print(f"  {cat}: {len(sents)} sentences")

# %%
def load_model(model_name):
    print(f"Loading model: {model_name} ...")
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        output_hidden_states=True,
    )
    model.eval()

    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    hidden_size = model.config.hidden_size
    print(f"  Model loaded  (hidden dim = {hidden_size})")
    if hasattr(model, "hf_device_map"):
        print(f"  Device map: {model.hf_device_map}")
    return tokenizer, model


tokenizer, model = load_model(MODEL_NAME)

# %%
def extract_embeddings(sentences_dict, tokenizer, model):
    all_embeddings, all_labels = [], []

    with torch.no_grad():
        for category, sents in sentences_dict.items():
            print(f"  Encoding {len(sents)} '{category}' sentences ...")
            for idx, sent in enumerate(sents):
                inputs = tokenizer(
                    sent,
                    return_tensors="pt",
                    truncation=True,
                    max_length=128,
                    padding="max_length",
                )
                first_device = next(model.parameters()).device
                inputs = {k: v.to(first_device) for k, v in inputs.items()}

                outputs = model(**inputs)
                last_hidden = outputs.hidden_states[-1]   # (1, seq_len, hidden_dim)

                attention_mask = inputs["attention_mask"].unsqueeze(-1).to(
                    device=last_hidden.device, dtype=last_hidden.dtype
                )
                masked = last_hidden * attention_mask
                pooled = masked.sum(dim=1) / attention_mask.sum(dim=1)

                vec = pooled.squeeze(0).float().cpu().numpy()
                all_embeddings.append(vec)
                all_labels.append(category)

                if (idx + 1) % 10 == 0:
                    print(f"    [{category}] {idx+1}/{len(sents)} done")

                if torch.cuda.is_available():
                    torch.cuda.empty_cache()

    embeddings = np.array(all_embeddings)
    labels     = np.array(all_labels)
    print(f"  Total embeddings: {embeddings.shape}")
    return embeddings, labels


print("Extracting embeddings ...")
os.makedirs(RESULTS_DIR, exist_ok=True)
embeddings, labels = extract_embeddings(sentences, tokenizer, model)

np.save(os.path.join(RESULTS_DIR, "embeddings.npy"), embeddings)
np.save(os.path.join(RESULTS_DIR, "labels.npy"), labels)
print(f"  Raw embeddings saved  ({embeddings.shape})")

# %%
df_hate = pd.read_excel(EXCEL_PATH_HATE)
hate_sentences = {}
for col in ["Hate Speech", "No-Hate Speech"]:
    raw = df_hate[col].dropna().astype(str).tolist()
    hate_sentences[col] = [s.strip() for s in raw if s.strip()]

hate_embeddings, hate_labels = extract_embeddings(hate_sentences, tokenizer, model)
np.save(os.path.join(RESULTS_DIR, "hate_embeddings.npy"), hate_embeddings)
np.save(os.path.join(RESULTS_DIR, "hate_labels.npy"), hate_labels)
print("Done — saved to Drive")


# Free GPU memory — we don't need the model anymore
del model
del tokenizer
if torch.cuda.is_available():
    torch.cuda.empty_cache()
print("  Model unloaded, GPU memory freed.")

# %%
import matplotlib.pyplot as plt
import os
import numpy as np


if "DRIVE_BASE" not in globals():
    DRIVE_BASE = "/content/drive/Shareddrives/thesis"
if "MODEL_NAME" not in globals():
    MODEL_NAME = "openai/gpt-oss-20b"
if "EXCEL_PATH" not in globals():
    EXCEL_PATH = os.path.join(DRIVE_BASE, "Sentences.xlsx")
if "EXCEL_PATH_CS" not in globals():
    EXCEL_PATH_CS = os.path.join(DRIVE_BASE, "comp_sci_sentences.xlsx")
if "EXCEL_PATH_HATE" not in globals():
    EXCEL_PATH_HATE = os.path.join(DRIVE_BASE, "Hate vs Not-Hate.xlsx")
if "RESULTS_DIR" not in globals():
    RESULTS_DIR = os.path.join(DRIVE_BASE, "results", "results_pca_gpt_oss_20b_sentences")

if "COLORS" not in globals():
    COLORS = {
        "Shakespeare":           "#E06C75",
        "Computer Science":      "#61AFEF",
        "Information Security":  "#98C379",
        "Theory of Computation": "#E5C07B",
        "Hate Speech":           "#C678DD",
        "No-Hate Speech":        "#56B6C2",
    }

if "CATEGORIES" not in globals():
    CATEGORIES = list(COLORS.keys())

os.makedirs(RESULTS_DIR, exist_ok=True)

# Reload saved embeddings
embeddings      = np.load(os.path.join(RESULTS_DIR, "embeddings.npy"))
labels          = np.load(os.path.join(RESULTS_DIR, "labels.npy"), allow_pickle=True)
hate_embeddings = np.load(os.path.join(RESULTS_DIR, "hate_embeddings.npy"))
hate_labels     = np.load(os.path.join(RESULTS_DIR, "hate_labels.npy"), allow_pickle=True)

print(f"Loaded embeddings: {embeddings.shape}, hate: {hate_embeddings.shape}")
# Out:
# Loaded embeddings: (400, 2880), hate: (200, 2880)

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.metrics.pairwise import cosine_distances, euclidean_distances
import os
import json
import numpy as np
import pandas as pd
import torch
import matplotlib
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist, mahalanobis
from scipy.special import rel_entr
from itertools import combinations

# Combine main (4 categories) + hate (2 categories)
all_embeddings = np.vstack([embeddings, hate_embeddings])
all_labels     = np.concatenate([labels, hate_labels])

ALL_CATS = ["Shakespeare", "Computer Science", "Information Security",
            "Theory of Computation", "Hate Speech", "No-Hate Speech"]

print(f"Combined embeddings: {all_embeddings.shape}")
for cat in ALL_CATS:
    print(f"  {cat}: {(all_labels == cat).sum()}")

# Reload sentences from Excel — aligned with embedding extraction order
def reload_sentences_map():
    sm = {}
    df1 = pd.read_excel(EXCEL_PATH)
    for col in ["Shakespeare", "Computer Science"]:
        raw = df1[col].dropna().astype(str).tolist()
        sm[col] = [s.strip() for s in raw if s.strip()]
    df2 = pd.read_excel(EXCEL_PATH_CS)
    for col in ["Information Security", "Theory of Computation"]:
        raw = df2[col].dropna().astype(str).tolist()
        sm[col] = [s.strip() for s in raw if s.strip()]
    df3 = pd.read_excel(EXCEL_PATH_HATE)
    for col in ["Hate Speech", "No-Hate Speech"]:
        raw = df3[col].dropna().astype(str).tolist()
        sm[col] = [s.strip() for s in raw if s.strip()]
    return sm

sentences_map = reload_sentences_map()

# Build sentence array aligned with all_labels
cat_counters  = {cat: 0 for cat in sentences_map}
all_sentences = []
for cat in all_labels:
    all_sentences.append(sentences_map[cat][cat_counters[cat]])
    cat_counters[cat] += 1
all_sentences = np.array(all_sentences)
print(f"Sentences aligned: {len(all_sentences)}")

# ── Subfolders ───────────────────────────────────────────────
DIR_DIST  = os.path.join(RESULTS_DIR, "distance_metrics");  os.makedirs(DIR_DIST,  exist_ok=True)
DIR_KL    = os.path.join(RESULTS_DIR, "kl_divergence");     os.makedirs(DIR_KL,    exist_ok=True)
DIR_SIL   = os.path.join(RESULTS_DIR, "silhouette");        os.makedirs(DIR_SIL,   exist_ok=True)
DIR_PCA   = os.path.join(RESULTS_DIR, "pca_plots");         os.makedirs(DIR_PCA,   exist_ok=True)
DIR_OVER  = os.path.join(RESULTS_DIR, "overlap");           os.makedirs(DIR_OVER,  exist_ok=True)
print("Subfolders ready.")
# Out:
# Combined embeddings: (600, 2880)
#   Shakespeare: 100
#   Computer Science: 100
#   Information Security: 100
#   Theory of Computation: 100
#   Hate Speech: 100
#   No-Hate Speech: 100
# Sentences aligned: 600
# Subfolders ready.

# %%
def compute_distances(emb, labs, tag, results_dir, n_pca=50):
    class_names = [c for c in ALL_CATS if c in set(labs)]
    class_data  = {c: emb[labs == c] for c in class_names}
    class_means = {c: d.mean(axis=0) for c, d in class_data.items()}

    # ── PCA-50 reduction + variance report ──────────────────────────────
    n_components = min(n_pca, emb.shape[0] - 1, emb.shape[1])
    pca50        = PCA(n_components=n_components)
    emb_r        = pca50.fit_transform(emb)
    var_explained = pca50.explained_variance_ratio_.sum()
    print(f"  PCA-{n_components} variance explained: {var_explained:.1%}  "
          f"(remaining {1-var_explained:.1%} discarded)")

    class_data_r  = {c: emb_r[labs == c] for c in class_names}
    class_means_r = {c: d.mean(axis=0) for c, d in class_data_r.items()}

    # ── Helper: avg pairwise Euclidean + cosine for any space ───────────
    def _euc_cos(cdata, cmeans):
        intra_e, intra_c, inter_e, inter_c = {}, {}, {}, {}
        for c in class_names:
            d    = cdata[c]
            n    = d.shape[0]
            triu = np.triu_indices(n, k=1)
            dmat_e = cdist(d, d, "euclidean")
            intra_e[c] = dmat_e[triu].mean() if len(triu[0]) > 0 else 0.0
            dmat_c = cdist(d, d, "cosine")
            intra_c[c] = dmat_c[triu].mean() if len(triu[0]) > 0 else 0.0
        for c1, c2 in combinations(class_names, 2):
            inter_e[(c1,c2)] = cdist(cdata[c1], cdata[c2], "euclidean").mean()
            inter_c[(c1,c2)] = cdist(cdata[c1], cdata[c2], "cosine").mean()
        return intra_e, intra_c, inter_e, inter_c

    intra_euc,   intra_cos,   inter_euc,   inter_cos   = _euc_cos(class_data,   class_means)
    intra_euc_r, intra_cos_r, inter_euc_r, inter_cos_r = _euc_cos(class_data_r, class_means_r)

    # ── Mahalanobis on PCA-50 space ─────────────────────────────────────
    pooled_cov = np.cov(emb_r, rowvar=False) + np.eye(n_components) * 1e-6
    try:
        cov_inv = np.linalg.inv(pooled_cov)
    except np.linalg.LinAlgError:
        cov_inv = np.linalg.pinv(pooled_cov)

    intra_mah, inter_mah = {}, {}
    for c in class_names:
        d = class_data_r[c]
        intra_mah[c] = np.mean([mahalanobis(d[i], class_means_r[c], cov_inv)
                                 for i in range(len(d))])
    for c1, c2 in combinations(class_names, 2):
        inter_mah[(c1,c2)] = mahalanobis(class_means_r[c1], class_means_r[c2], cov_inv)

    # ── Report ───────────────────────────────────────────────────────────
    report = ["=" * 85,
              f"DISTANCE ANALYSIS  —  {tag}",
              f"Model: {MODEL_NAME}",
              f"PCA-{n_components} variance explained: {var_explained:.1%}",
              "=" * 85]

    for space_label, intra_e, intra_c, inter_e, inter_c, show_mah in [
        (f"FULL {emb.shape[1]}-d SPACE",    intra_euc,   intra_cos,   inter_euc,   inter_cos,   False),
        (f"PCA-{n_components} SPACE",        intra_euc_r, intra_cos_r, inter_euc_r, inter_cos_r, True),
    ]:
        report.append(f"\n  ── {space_label} ──")
        report.append(f"  INTRA-CLASS:")
        header = f"  {'Class':<25} {'Avg Euclidean':>15} {'Avg Cosine':>12}"
        if show_mah: header += f" {'Mahalanobis':>13}"
        header += f" {'N':>6}"
        report.append(header)
        report.append(f"  {'-'*(len(header)-2)}")
        for c in class_names:
            row = f"  {c:<25} {intra_e[c]:>15.4f} {intra_c[c]:>12.4f}"
            if show_mah: row += f" {intra_mah[c]:>13.4f}"
            row += f" {class_data[c].shape[0]:>6}"
            report.append(row)

        report.append(f"\n  INTER-CLASS:")
        header2 = f"  {'Pair':<40} {'Avg Euclidean':>15} {'Avg Cosine':>12}"
        if show_mah: header2 += f" {'Mahalanobis':>13}"
        report.append(header2)
        report.append(f"  {'-'*(len(header2)-2)}")
        for c1, c2 in combinations(class_names, 2):
            pair = f"{c1} vs {c2}"
            row  = f"  {pair:<40} {inter_e[(c1,c2)]:>15.4f} {inter_c[(c1,c2)]:>12.4f}"
            if show_mah: row += f" {inter_mah[(c1,c2)]:>13.4f}"
            report.append(row)

        report.append(f"\n  SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine")
        if show_mah: report[-1] += " & Mahalanobis"
        header3 = f"  {'Pair':<40} {'Euc ratio':>10} {'Cos ratio':>10}"
        if show_mah: header3 += f" {'Mah ratio':>10}"
        report.append(header3)
        report.append(f"  {'-'*(len(header3)-2)}")
        for c1, c2 in combinations(class_names, 2):
            avg_ie = np.mean([intra_e[c1], intra_e[c2]])
            avg_ic = np.mean([intra_c[c1], intra_c[c2]])
            re     = inter_e[(c1,c2)] / avg_ie if avg_ie > 0 else float("inf")
            rc     = inter_c[(c1,c2)] / avg_ic if avg_ic > 0 else float("inf")
            pair   = f"{c1} vs {c2}"
            row    = f"  {pair:<40} {re:>10.4f} {rc:>10.4f}"
            if show_mah:
                avg_im = np.mean([intra_mah[c1], intra_mah[c2]])
                rm     = inter_mah[(c1,c2)] / avg_im if avg_im > 0 else float("inf")
                row   += f" {rm:>10.4f}"
            report.append(row)

    report.append(f"\n{'='*85}")
    txt = "\n".join(report)
    print(txt)

    fname_txt = f"distance_analysis_{tag.lower().replace(' ','_')}.txt"
    with open(os.path.join(results_dir, fname_txt), "w", encoding="utf-8") as f:
        f.write(txt)
    print(f"  Saved {fname_txt}")

    # ── Heatmaps (one per metric, both spaces) ────────────────────────────
    n_cls = len(class_names)
    short = [c.replace("Theory of Computation","ToC").replace("Information Security","InfoSec")
              .replace("Computer Science","CS").replace("No-Hate Speech","No-Hate")
              .replace("Hate Speech","Hate") for c in class_names]

    heatmap_specs = [
        (f"Euclidean (full {emb.shape[1]}-d)",  intra_euc,   inter_euc,   "full_euclidean"),
        (f"Cosine (full {emb.shape[1]}-d)",      intra_cos,   inter_cos,   "full_cosine"),
        (f"Euclidean (PCA-{n_components})",      intra_euc_r, inter_euc_r, "pca_euclidean"),
        (f"Cosine (PCA-{n_components})",         intra_cos_r, inter_cos_r, "pca_cosine"),
        (f"Mahalanobis (PCA-{n_components})",    intra_mah,   inter_mah,   "pca_mahalanobis"),
    ]
    for metric_name, intra_d, inter_d, metric_key in heatmap_specs:
        mat = np.zeros((n_cls, n_cls))
        for i, ci in enumerate(class_names):
            mat[i, i] = intra_d[ci]
            for j, cj in enumerate(class_names):
                if i < j:
                    mat[i, j] = inter_d[(ci, cj)]
                    mat[j, i] = inter_d[(ci, cj)]

        fig, ax = plt.subplots(figsize=(9, 7))
        im = ax.imshow(mat, cmap="YlOrRd", interpolation="nearest")
        plt.colorbar(im, ax=ax, shrink=0.8)
        for i in range(n_cls):
            for j in range(n_cls):
                color = "white" if mat[i, j] > mat.max() * 0.65 else "black"
                tag2  = "(intra)" if i == j else "(inter)"
                ax.text(j, i, f"{mat[i,j]:.3f}\n{tag2}",
                        ha="center", va="center", fontsize=9, fontweight="bold", color=color)
        ax.set_xticks(range(n_cls)); ax.set_xticklabels(short, fontsize=10, rotation=30, ha="right")
        ax.set_yticks(range(n_cls)); ax.set_yticklabels(short, fontsize=10)
        ax.set_title(f"{metric_name} — {tag}\nGPT-OSS-20B", fontsize=12, fontweight="bold")
        plt.tight_layout()
        fname_png = f"dist_{metric_key}_{tag.lower().replace(' ','_')}.png"
        plt.savefig(os.path.join(results_dir, fname_png), dpi=150, bbox_inches="tight")
        print(f"  Saved {fname_png}")
        plt.show()
        plt.close()


print("\n─── Distance Analysis: all 6 categories ───────────────────")
compute_distances(all_embeddings, all_labels, "All Categories", DIR_DIST)

PAIRS = [
    ("Computer Science", "Shakespeare"),
    ("Theory of Computation", "Information Security"),
    ("Hate Speech", "No-Hate Speech"),
]
for c1, c2 in PAIRS:
    mask = np.isin(all_labels, [c1, c2])
    print(f"\n─── Distance Analysis: {c1} vs {c2} ───")
    compute_distances(all_embeddings[mask], all_labels[mask], f"{c1} vs {c2}", DIR_DIST)
# Out:
# ─── Distance Analysis: all 6 categories ───────────────────
#   PCA-50 variance explained: 68.3%  (remaining 31.7% discarded)
# =====================================================================================
# DISTANCE ANALYSIS  —  All Categories
# Model: openai/gpt-oss-20b
# PCA-50 variance explained: 68.3%
# =====================================================================================
#
#   ── FULL 2880-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Shakespeare                      136.6736       0.2615    100
#   Computer Science                 150.9724       0.2828    100
#   Information Security             144.0265       0.2599    100
#   Theory of Computation            136.6244       0.2517    100
#   Hate Speech                       92.4056       0.2096    100
#   No-Hate Speech                   101.1370       0.2337    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Shakespeare vs Computer Science                 171.2862       0.3827
#   Shakespeare vs Information Security             171.9642       0.3879
#   Shakespeare vs Theory of Computation            171.1211       0.4000
#   Shakespeare vs Hate Speech                      151.3866       0.3850
#   Shakespeare vs No-Hate Speech                   152.0852       0.3873
#   Computer Science vs Information Security        153.8436       0.2951
#   Computer Science vs Theory of Computation        159.0026       0.3261
#   Computer Science vs Hate Speech                 173.8735       0.4694
#   Computer Science vs No-Hate Speech              173.1215       0.4608
#   Information Security vs Theory of Computation        163.5915       0.3473
#   Information Security vs Hate Speech             171.0631       0.4573
#   Information Security vs No-Hate Speech          170.4347       0.4494
#   Theory of Computation vs Hate Speech            168.9582       0.4751
#   Theory of Computation vs No-Hate Speech         169.0712       0.4698
#   Hate Speech vs No-Hate Speech                    97.4849       0.2242
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Shakespeare vs Computer Science              1.1910     1.4063
#   Shakespeare vs Information Security          1.2253     1.4879
#   Shakespeare vs Theory of Computation         1.2523     1.5588
#   Shakespeare vs Hate Speech                   1.3217     1.6346
#   Shakespeare vs No-Hate Speech                1.2790     1.5642
#   Computer Science vs Information Security     1.0430     1.0875
#   Computer Science vs Theory of Computation     1.1057     1.2203
#   Computer Science vs Hate Speech              1.4288     1.9065
#   Computer Science vs No-Hate Speech           1.3734     1.7841
#   Information Security vs Theory of Computation     1.1658     1.3578
#   Information Security vs Hate Speech          1.4470     1.9484
#   Information Security vs No-Hate Speech       1.3904     1.8207
#   Theory of Computation vs Hate Speech         1.4754     2.0602
#   Theory of Computation vs No-Hate Speech      1.4222     1.9356
#   Hate Speech vs No-Hate Speech                1.0074     1.0115
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Shakespeare                       83.3434       0.4731        6.4601    100
#   Computer Science                 108.9221       0.6515        8.3770    100
#   Information Security             101.1966       0.5764        7.7666    100
#   Theory of Computation            101.1015       0.5386        7.4487    100
#   Hate Speech                       72.2560       0.3467        4.1044    100
#   No-Hate Speech                    78.3903       0.4278        4.4305    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Shakespeare vs Computer Science                 134.9610       1.0999        3.2350
#   Shakespeare vs Information Security             136.5578       1.1390        3.2516
#   Shakespeare vs Theory of Computation            139.2350       1.1380        3.2974
#   Shakespeare vs Hate Speech                      124.4306       1.0311        2.9542
#   Shakespeare vs No-Hate Speech                   123.7708       1.0281        2.9600
#   Computer Science vs Information Security        114.3303       0.7258        2.9547
#   Computer Science vs Theory of Computation        125.2530       0.8343        3.1179
#   Computer Science vs Hate Speech                 152.4976       1.4048        2.9044
#   Computer Science vs No-Hate Speech              150.4331       1.3728        2.8377
#   Information Security vs Theory of Computation        131.9434       0.9348        3.2367
#   Information Security vs Hate Speech             149.9185       1.3705        2.9233
#   Information Security vs No-Hate Speech          148.0042       1.3416        2.9091
#   Theory of Computation vs Hate Speech            151.0070       1.3394        2.9826
#   Theory of Computation vs No-Hate Speech         149.9604       1.3268        2.9638
#   Hate Speech vs No-Hate Speech                    76.0776       0.3939        1.2947
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Shakespeare vs Computer Science              1.4039     1.9562     0.4361
#   Shakespeare vs Information Security          1.4800     2.1706     0.4571
#   Shakespeare vs Theory of Computation         1.5098     2.2498     0.4742
#   Shakespeare vs Hate Speech                   1.5994     2.5154     0.5593
#   Shakespeare vs No-Hate Speech                1.5306     2.2823     0.5436
#   Computer Science vs Information Security     1.0882     1.1823     0.3661
#   Computer Science vs Theory of Computation     1.1928     1.4021     0.3940
#   Computer Science vs Hate Speech              1.6834     2.8148     0.4654
#   Computer Science vs No-Hate Speech           1.6062     2.5438     0.4431
#   Information Security vs Theory of Computation     1.3044     1.6767     0.4255
#   Information Security vs Hate Speech          1.7286     2.9691     0.4925
#   Information Security vs No-Hate Speech       1.6483     2.6718     0.4770
#   Theory of Computation vs Hate Speech         1.7421     3.0259     0.5163
#   Theory of Computation vs No-Hate Speech      1.6709     2.7457     0.4990
#   Hate Speech vs No-Hate Speech                1.0100     1.0171     0.3034
#
# =====================================================================================
#   Saved distance_analysis_all_categories.txt
#   Saved dist_full_euclidean_all_categories.png
#   Saved dist_full_cosine_all_categories.png
#   Saved dist_pca_euclidean_all_categories.png
#   Saved dist_pca_cosine_all_categories.png
#   Saved dist_pca_mahalanobis_all_categories.png
# ─── Distance Analysis: Computer Science vs Shakespeare ───
#   PCA-50 variance explained: 68.3%  (remaining 31.7% discarded)
# =====================================================================================
# DISTANCE ANALYSIS  —  Computer Science vs Shakespeare
# Model: openai/gpt-oss-20b
# PCA-50 variance explained: 68.3%
# =====================================================================================
#
#   ── FULL 2880-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Shakespeare                      136.6736       0.2615    100
#   Computer Science                 150.9724       0.2828    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Shakespeare vs Computer Science                 171.2862       0.3827
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Shakespeare vs Computer Science              1.1910     1.4063
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Shakespeare                      100.9546       0.6836        6.2454    100
#   Computer Science                 120.6181       0.7678        7.2304    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Shakespeare vs Computer Science                 145.5748       1.2764        1.9739
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Shakespeare vs Computer Science              1.3140     1.7589     0.2929
#
# =====================================================================================
#   Saved distance_analysis_computer_science_vs_shakespeare.txt
#   Saved dist_full_euclidean_computer_science_vs_shakespeare.png
#   Saved dist_full_cosine_computer_science_vs_shakespeare.png
#   Saved dist_pca_euclidean_computer_science_vs_shakespeare.png
#   Saved dist_pca_cosine_computer_science_vs_shakespeare.png
#   Saved dist_pca_mahalanobis_computer_science_vs_shakespeare.png
# ─── Distance Analysis: Theory of Computation vs Information Security ───
#   PCA-50 variance explained: 72.7%  (remaining 27.3% discarded)
# =====================================================================================
# DISTANCE ANALYSIS  —  Theory of Computation vs Information Security
# Model: openai/gpt-oss-20b
# PCA-50 variance explained: 72.7%
# =====================================================================================
#
#   ── FULL 2880-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Information Security             144.0265       0.2599    100
#   Theory of Computation            136.6244       0.2517    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Information Security vs Theory of Computation        163.5915       0.3473
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Information Security vs Theory of Computation     1.1658     1.3578
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Information Security             116.4806       0.7929        7.2841    100
#   Theory of Computation            112.7882       0.7924        6.4867    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Information Security vs Theory of Computation        142.5151       1.2147        1.9570
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Information Security vs Theory of Computation     1.2432     1.5324     0.2842
#
# =====================================================================================
#   Saved distance_analysis_theory_of_computation_vs_information_security.txt
#   Saved dist_full_euclidean_theory_of_computation_vs_information_security.png
#   Saved dist_full_cosine_theory_of_computation_vs_information_security.png
#   Saved dist_pca_euclidean_theory_of_computation_vs_information_security.png
#   Saved dist_pca_cosine_theory_of_computation_vs_information_security.png
#   Saved dist_pca_mahalanobis_theory_of_computation_vs_information_security.png
# ─── Distance Analysis: Hate Speech vs No-Hate Speech ───
#   PCA-50 variance explained: 86.2%  (remaining 13.8% discarded)
# =====================================================================================
# DISTANCE ANALYSIS  —  Hate Speech vs No-Hate Speech
# Model: openai/gpt-oss-20b
# PCA-50 variance explained: 86.2%
# =====================================================================================
#
#   ── FULL 2880-d SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine      N
#   -------------------------------------------------------------
#   Hate Speech                       92.4056       0.2096    100
#   No-Hate Speech                   101.1370       0.2337    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine
#   ---------------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                    97.4849       0.2242
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine
#   Pair                                      Euc ratio  Cos ratio
#   --------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                1.0074     1.0115
#
#   ── PCA-50 SPACE ──
#   INTRA-CLASS:
#   Class                       Avg Euclidean   Avg Cosine   Mahalanobis      N
#   ---------------------------------------------------------------------------
#   Hate Speech                       84.1689       0.9963        6.3442    100
#   No-Hate Speech                    93.3632       0.9987        7.2514    100
#
#   INTER-CLASS:
#   Pair                                       Avg Euclidean   Avg Cosine   Mahalanobis
#   -----------------------------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                    89.5932       1.0113        1.4003
#
#   SEPARABILITY RATIO (inter / avg intra)  —  Euclidean & Cosine & Mahalanobis
#   Pair                                      Euc ratio  Cos ratio  Mah ratio
#   -------------------------------------------------------------------------
#   Hate Speech vs No-Hate Speech                1.0093     1.0138     0.2060
#
# =====================================================================================
#   Saved distance_analysis_hate_speech_vs_no-hate_speech.txt
#   Saved dist_full_euclidean_hate_speech_vs_no-hate_speech.png
#   Saved dist_full_cosine_hate_speech_vs_no-hate_speech.png
#   Saved dist_pca_euclidean_hate_speech_vs_no-hate_speech.png
#   Saved dist_pca_cosine_hate_speech_vs_no-hate_speech.png
#   Saved dist_pca_mahalanobis_hate_speech_vs_no-hate_speech.png

# %%
def compute_kl_divergence(emb, labs, tag, results_dir):
    class_names = [c for c in ALL_CATS if c in set(labs)]
    n_bins, eps = 50, 1e-10
    class_data  = {c: emb[labs == c] for c in class_names}
    g_min, g_max = emb.min(axis=0), emb.max(axis=0)

    class_dists = {}
    for c in class_names:
        dists = []
        for d in range(emb.shape[1]):
            vals   = class_data[c][:, d]
            lo, hi = g_min[d], g_max[d]
            if hi - lo < 1e-12:
                hist = np.ones(n_bins) / n_bins
            else:
                hist, _ = np.histogram(vals, bins=n_bins, range=(lo, hi))
                hist = hist.astype(np.float64) + eps
                hist /= hist.sum()
            dists.append(hist)
        class_dists[c] = np.array(dists)

    n_cls     = len(class_names)
    kl_matrix = np.zeros((n_cls, n_cls))
    report    = ["=" * 70, f"KL DIVERGENCE — {tag}", f"Model: {MODEL_NAME}", "=" * 70]
    report.append(f"\n  {'P \\ Q':<25} " + " ".join(f"{c:>15}" for c in class_names))
    report.append(f"  {'-'*(25 + 16*n_cls)}")

    for i, ci in enumerate(class_names):
        row = []
        for j, cj in enumerate(class_names):
            if i == j:
                kl_matrix[i, j] = 0.0
                row.append(f"{'0.0000':>15}")
            else:
                kl = np.mean([np.sum(rel_entr(class_dists[ci][k], class_dists[cj][k]))
                              for k in range(emb.shape[1])])
                kl_matrix[i, j] = kl
                row.append(f"{kl:>15.4f}")
        report.append(f"  {ci:<25} " + " ".join(row))

    report.append(f"\n{'='*70}")
    txt = "\n".join(report)
    print(txt)

    fname_txt = f"kl_divergence_{tag.lower().replace(' ','_')}.txt"
    with open(os.path.join(results_dir, fname_txt), "w", encoding="utf-8") as f:
        f.write(txt)
    print(f"  Saved {fname_txt}")

    short = [c.replace("Theory of Computation","ToC").replace("Information Security","InfoSec")
              .replace("Computer Science","CS").replace("No-Hate Speech","No-Hate")
              .replace("Hate Speech","Hate") for c in class_names]

    fig, ax = plt.subplots(figsize=(max(7, n_cls*1.4), max(6, n_cls*1.2)))
    im = ax.imshow(kl_matrix, cmap="Blues", interpolation="nearest")
    plt.colorbar(im, ax=ax, shrink=0.8, label="KL Divergence (nats)")
    for i in range(n_cls):
        for j in range(n_cls):
            color = "white" if kl_matrix[i, j] > kl_matrix.max() * 0.65 else "black"
            ax.text(j, i, f"{kl_matrix[i,j]:.3f}",
                    ha="center", va="center", fontsize=10, fontweight="bold", color=color)
    ax.set_xticks(range(n_cls)); ax.set_xticklabels(short, fontsize=10, rotation=30, ha="right")
    ax.set_yticks(range(n_cls)); ax.set_yticklabels(short, fontsize=10)
    ax.set_xlabel("Q (reference)", fontsize=11)
    ax.set_ylabel("P (source)", fontsize=11)
    ax.set_title(f"KL Divergence — {tag}\nGPT-OSS-20B  |  KL(P‖Q) avg over neurons",
                 fontsize=12, fontweight="bold")
    plt.tight_layout()
    fname_png = f"kl_divergence_{tag.lower().replace(' ','_')}.png"
    plt.savefig(os.path.join(results_dir, fname_png), dpi=150, bbox_inches="tight")
    print(f"  Saved {fname_png}")
    plt.show()
    plt.close()


print("\n─── KL Divergence: all 6 categories ───────────────────────")
compute_kl_divergence(all_embeddings, all_labels, "All Categories", DIR_KL)

for c1, c2 in PAIRS:
    mask = np.isin(all_labels, [c1, c2])
    print(f"\n─── KL Divergence: {c1} vs {c2} ───")
    compute_kl_divergence(all_embeddings[mask], all_labels[mask], f"{c1} vs {c2}", DIR_KL)
# Out:
# ─── KL Divergence: all 6 categories ───────────────────────
# ======================================================================
# KL DIVERGENCE — All Categories
# Model: openai/gpt-oss-20b
# ======================================================================
#
#   P \ Q                         Shakespeare Computer Science Information Security Theory of Computation     Hate Speech  No-Hate Speech
#   -------------------------------------------------------------------------------------------------------------------------
#   Shakespeare                        0.0000          3.5857          3.9869          4.6194          7.5275          6.9243
#   Computer Science                   4.4509          0.0000          2.8398          3.6798          9.1377          8.4563
#   Information Security               4.6111          2.6355          0.0000          4.2040          9.3084          8.6076
#   Theory of Computation              4.7751          3.0095          3.7546          0.0000          9.4691          8.8086
#   Hate Speech                        2.5162          3.1192          3.5261          4.1331          0.0000          1.0110
#   No-Hate Speech                     2.5868          3.1005          3.4610          4.0991          1.4364          0.0000
#
# ======================================================================
#   Saved kl_divergence_all_categories.txt
#   Saved kl_divergence_all_categories.png
# ─── KL Divergence: Computer Science vs Shakespeare ───
# ======================================================================
# KL DIVERGENCE — Computer Science vs Shakespeare
# Model: openai/gpt-oss-20b
# ======================================================================
#
#   P \ Q                         Shakespeare Computer Science
#   ---------------------------------------------------------
#   Shakespeare                        0.0000          3.9003
#   Computer Science                   4.7313          0.0000
#
# ======================================================================
#   Saved kl_divergence_computer_science_vs_shakespeare.txt
#   Saved kl_divergence_computer_science_vs_shakespeare.png
# ─── KL Divergence: Theory of Computation vs Information Security ───
# ======================================================================
# KL DIVERGENCE — Theory of Computation vs Information Security
# Model: openai/gpt-oss-20b
# ======================================================================
#
#   P \ Q                     Information Security Theory of Computation
#   ---------------------------------------------------------
#   Information Security               0.0000          4.6893
#   Theory of Computation              4.2442          0.0000
#
# ======================================================================
#   Saved kl_divergence_theory_of_computation_vs_information_security.txt
#   Saved kl_divergence_theory_of_computation_vs_information_security.png
# ─── KL Divergence: Hate Speech vs No-Hate Speech ───
# ======================================================================
# KL DIVERGENCE — Hate Speech vs No-Hate Speech
# Model: openai/gpt-oss-20b
# ======================================================================
#
#   P \ Q                         Hate Speech  No-Hate Speech
#   ---------------------------------------------------------
#   Hate Speech                        0.0000          2.4642
#   No-Hate Speech                     3.0200          0.0000
#
# ======================================================================
#   Saved kl_divergence_hate_speech_vs_no-hate_speech.txt
#   Saved kl_divergence_hate_speech_vs_no-hate_speech.png

# %%
def compute_silhouette(emb, labs, tag, results_dir, n_pca=50):
    # Reduce to 50 PCA dims first — silhouette in 4096-d is dominated by
    # the same concentration-of-measure issue as raw Euclidean distances.
    pca_red = PCA(n_components=min(n_pca, emb.shape[0]-1, emb.shape[1]))
    emb_r   = pca_red.fit_transform(emb)

    score = silhouette_score(emb_r, labs)
    samples = silhouette_samples(emb_r, labs)

    class_names = [c for c in ALL_CATS if c in set(labs)]
    report = [
        "=" * 60,
        f"SILHOUETTE SCORES — {tag}",
        f"Model: {MODEL_NAME}  |  PCA reduced to {emb_r.shape[1]} dims",
        "=" * 60,
        f"\n  Overall silhouette score: {score:.4f}",
        f"  (range -1 to +1; higher = better separated)\n",
        f"  {'Class':<25} {'Mean silhouette':>16} {'N':>6}",
        f"  {'-'*49}",
    ]
    for c in class_names:
        idx = labs == c
        report.append(f"  {c:<25} {samples[idx].mean():>16.4f} {idx.sum():>6}")

    report.append(f"\n{'='*60}")
    txt = "\n".join(report)
    print(txt)

    fname = f"silhouette_{tag.lower().replace(' ','_')}.txt"
    with open(os.path.join(results_dir, fname), "w", encoding="utf-8") as f:
        f.write(txt)
    print(f"  Saved {fname}")

    # Bar chart
    class_scores = [samples[labs == c].mean() for c in class_names]
    short = [c.replace("Theory of Computation","ToC").replace("Information Security","InfoSec")
              .replace("Computer Science","CS").replace("No-Hate Speech","No-Hate")
              .replace("Hate Speech","Hate") for c in class_names]
    bar_colors = [COLORS[c] for c in class_names]

    fig, ax = plt.subplots(figsize=(max(7, len(class_names)*1.3), 5))
    bars = ax.bar(short, class_scores, color=bar_colors, edgecolor="white", linewidth=0.8)
    ax.axhline(score, color="black", linestyle="--", linewidth=1.2, label=f"Overall: {score:.3f}")
    ax.axhline(0, color="grey", linestyle=":", linewidth=0.8)
    for bar, val in zip(bars, class_scores):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
                f"{val:.3f}", ha="center", va="bottom", fontsize=10, fontweight="bold")
    ax.set_ylabel("Mean Silhouette Score", fontsize=11)
    ax.set_title(f"Silhouette Scores — {tag}\nGPT-OSS-20B (PCA-{emb_r.shape[1]})",
                 fontsize=12, fontweight="bold")
    ax.legend(fontsize=10)
    ax.set_ylim(min(class_scores) - 0.05, max(class_scores) + 0.08)
    plt.tight_layout()
    fname_png = f"silhouette_{tag.lower().replace(' ','_')}.png"
    plt.savefig(os.path.join(results_dir, fname_png), dpi=150, bbox_inches="tight")
    print(f"  Saved {fname_png}")
    plt.show()
    plt.close()

    return score


print("\n─── Silhouette: all 6 categories ───────────────────────────")
compute_silhouette(all_embeddings, all_labels, "All Categories", DIR_SIL)

for c1, c2 in PAIRS:
    mask = np.isin(all_labels, [c1, c2])
    print(f"\n─── Silhouette: {c1} vs {c2} ───")
    compute_silhouette(all_embeddings[mask], all_labels[mask], f"{c1} vs {c2}", DIR_SIL)
# Out:
# ─── Silhouette: all 6 categories ───────────────────────────
# ============================================================
# SILHOUETTE SCORES — All Categories
# Model: openai/gpt-oss-20b  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.1119
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Shakespeare                         0.3204    100
#   Computer Science                    0.0342    100
#   Information Security                0.1138    100
#   Theory of Computation               0.1853    100
#   Hate Speech                         0.0514    100
#   No-Hate Speech                     -0.0340    100
#
# ============================================================
#   Saved silhouette_all_categories.txt
#   Saved silhouette_all_categories.png
# ─── Silhouette: Computer Science vs Shakespeare ───
# ============================================================
# SILHOUETTE SCORES — Computer Science vs Shakespeare
# Model: openai/gpt-oss-20b  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.2398
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Shakespeare                         0.3092    100
#   Computer Science                    0.1704    100
#
# ============================================================
#   Saved silhouette_computer_science_vs_shakespeare.txt
#   Saved silhouette_computer_science_vs_shakespeare.png
# ─── Silhouette: Theory of Computation vs Information Security ───
# ============================================================
# SILHOUETTE SCORES — Theory of Computation vs Information Security
# Model: openai/gpt-oss-20b  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.1938
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Information Security                0.1828    100
#   Theory of Computation               0.2049    100
#
# ============================================================
#   Saved silhouette_theory_of_computation_vs_information_security.txt
#   Saved silhouette_theory_of_computation_vs_information_security.png
# ─── Silhouette: Hate Speech vs No-Hate Speech ───
# ============================================================
# SILHOUETTE SCORES — Hate Speech vs No-Hate Speech
# Model: openai/gpt-oss-20b  |  PCA reduced to 50 dims
# ============================================================
#
#   Overall silhouette score: 0.0099
#   (range -1 to +1; higher = better separated)
#
#   Class                      Mean silhouette      N
#   -------------------------------------------------
#   Hate Speech                         0.0617    100
#   No-Hate Speech                     -0.0419    100
#
# ============================================================
#   Saved silhouette_hate_speech_vs_no-hate_speech.txt
#   Saved silhouette_hate_speech_vs_no-hate_speech.png

# %%
def pca_plot(emb, labs, cats, title, fname_base, results_dir):
    mask    = np.isin(labs, cats)
    emb_sub = emb[mask]
    lab_sub = labs[mask]

    # 2D
    pca2 = PCA(n_components=2)
    X2   = pca2.fit_transform(emb_sub)
    evr2 = pca2.explained_variance_ratio_

    fig, ax = plt.subplots(figsize=(10, 8))
    for cat in cats:
        idx = lab_sub == cat
        ax.scatter(X2[idx, 0], X2[idx, 1], c=COLORS[cat], label=cat,
                   alpha=0.75, edgecolors="w", linewidths=0.5, s=60)
    ax.set_xlabel(f"PC 1  ({evr2[0]:.1%})", fontsize=12)
    ax.set_ylabel(f"PC 2  ({evr2[1]:.1%})", fontsize=12)
    ax.set_title(f"GPT-OSS-20B — 2D PCA\n{title}", fontsize=14, fontweight="bold")
    ax.legend(fontsize=10, loc="best")
    ax.grid(True, linestyle="--", alpha=0.4)
    plt.tight_layout()
    p2 = os.path.join(results_dir, f"{fname_base}_2d.png")
    plt.savefig(p2, dpi=150, bbox_inches="tight")
    print(f"  Saved {p2}")
    plt.show(); plt.close()

    # 3D
    pca3 = PCA(n_components=3)
    X3   = pca3.fit_transform(emb_sub)
    evr3 = pca3.explained_variance_ratio_

    fig = plt.figure(figsize=(12, 10))
    ax  = fig.add_subplot(111, projection="3d")
    for cat in cats:
        idx = lab_sub == cat
        ax.scatter(X3[idx,0], X3[idx,1], X3[idx,2], c=COLORS[cat], label=cat,
                   alpha=0.75, edgecolors="w", linewidths=0.5, s=60)
    ax.set_xlabel(f"PC 1  ({evr3[0]:.1%})", fontsize=10)
    ax.set_ylabel(f"PC 2  ({evr3[1]:.1%})", fontsize=10)
    ax.set_zlabel(f"PC 3  ({evr3[2]:.1%})", fontsize=10)
    ax.set_title(f"GPT-OSS-20B — 3D PCA\n{title}", fontsize=14, fontweight="bold")
    ax.legend(fontsize=10, loc="best")
    plt.tight_layout()
    p3 = os.path.join(results_dir, f"{fname_base}_3d.png")
    plt.savefig(p3, dpi=150, bbox_inches="tight")
    print(f"  Saved {p3}")
    plt.show(); plt.close()


print("\n─── PCA: all 6 categories ──────────────────────────────────")
pca_plot(all_embeddings, all_labels, ALL_CATS,
         "All 6 Categories", "pca_all", DIR_PCA)

print("\n─── PCA: pairwise ──────────────────────────────────────────")
pair_meta = [
    (["Computer Science", "Shakespeare"],               "CS vs Shakespeare",          "pca_cs_shakespeare"),
    (["Theory of Computation", "Information Security"], "ToC vs Information Security", "pca_toc_infosec"),
    (["Hate Speech", "No-Hate Speech"],                 "Hate vs No-Hate Speech",     "pca_hate"),
]
for cats, title, fname in pair_meta:
    print(f"\n  {title}")
    pca_plot(all_embeddings, all_labels, cats, title, fname, DIR_PCA)
# Out:
# ─── PCA: all 6 categories ──────────────────────────────────
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_all_2d.png
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_all_3d.png
# ─── PCA: pairwise ──────────────────────────────────────────
#
#   CS vs Shakespeare
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_cs_shakespeare_2d.png
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_cs_shakespeare_3d.png
#   ToC vs Information Security
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_toc_infosec_2d.png
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_toc_infosec_3d.png
#   Hate vs No-Hate Speech
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_hate_2d.png
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/pca_plots/pca_hate_3d.png

# %%
def find_overlapping_sentences(emb, labs, sents, c1, c2, top_k=5, results_dir=None, n_pca=50):
    idx1 = np.where(labs == c1)[0]
    idx2 = np.where(labs == c2)[0]

    # ── Full 4096-d Euclidean ────────────────────────────────────────────
    dmat_full = cdist(emb[idx1], emb[idx2], "euclidean")

    # ── PCA-50 Euclidean ─────────────────────────────────────────────────
    n_components = min(n_pca, emb.shape[0] - 1, emb.shape[1])
    pca50        = PCA(n_components=n_components)
    emb_r        = pca50.fit_transform(emb)
    var_explained = pca50.explained_variance_ratio_.sum()
    dmat_pca  = cdist(emb_r[idx1], emb_r[idx2], "euclidean")

    report = [
        "=" * 80,
        f"MOST OVERLAPPING SENTENCE PAIRS  —  {c1}  vs  {c2}",
        "=" * 80,
    ]

    for space_label, dmat in [
        (f"Full {emb.shape[1]}-d Euclidean", dmat_full),
        (f"PCA-{n_components} Euclidean  (variance explained: {var_explained:.1%})", dmat_pca),
    ]:
        report.append(f"\n  ── {space_label} ──")
        flat = dmat.flatten()
        top  = np.argsort(flat)[:top_k]
        for rank, flat_idx in enumerate(top, 1):
            i, j  = np.unravel_index(flat_idx, dmat.shape)
            dist  = dmat[i, j]
            s1    = sents[idx1[i]]
            s2    = sents[idx2[j]]
            report.append(f"\n  Rank {rank}  |  distance = {dist:.4f}")
            report.append(f"  [{c1}]  {s1}")
            report.append(f"  [{c2}]  {s2}")

    txt = "\n".join(report)
    print(txt)

    if results_dir:
        safe  = f"{c1}_{c2}".lower().replace(" ", "_")
        fname = os.path.join(results_dir, f"overlap_{safe}.txt")
        with open(fname, "w", encoding="utf-8") as f:
            f.write(txt)
        print(f"\n  Saved {fname}")


print("\n─── Overlapping sentences ──────────────────────────────────")
for c1, c2 in PAIRS:
    find_overlapping_sentences(all_embeddings, all_labels, all_sentences,
                               c1, c2, top_k=5, results_dir=DIR_OVER)
# Out:
# ─── Overlapping sentences ──────────────────────────────────
# ================================================================================
# MOST OVERLAPPING SENTENCE PAIRS  —  Computer Science  vs  Shakespeare
# ================================================================================
#
#   ── Full 2880-d Euclidean ──
#
#   Rank 1  |  distance = 120.5090
#   [Computer Science]  A data structure organizes and stores data efficiently.
#   [Shakespeare]  The worst is not so long as we can say, “This is the worst.”
#
#   Rank 2  |  distance = 124.1017
#   [Computer Science]  Recursion solves problems by reducing them to smaller instances.
#   [Shakespeare]  The worst is not so long as we can say, “This is the worst.”
#
#   Rank 3  |  distance = 125.5416
#   [Computer Science]  Scalability refers to handling increased workload effectively.
#   [Shakespeare]  Sweet are the uses of adversity.
#
#   Rank 4  |  distance = 125.5789
#   [Computer Science]  A data structure organizes and stores data efficiently.
#   [Shakespeare]  Sweet are the uses of adversity.
#
#   Rank 5  |  distance = 126.2300
#   [Computer Science]  Throughput measures the number of operations per unit time.
#   [Shakespeare]  The worst is not so long as we can say, “This is the worst.”
#
#   ── PCA-50 Euclidean  (variance explained: 68.3%) ──
#
#   Rank 1  |  distance = 78.5606
#   [Computer Science]  Scalability refers to handling increased workload effectively.
#   [Shakespeare]  Reputation is an idle and most false imposition.
#
#   Rank 2  |  distance = 79.7063
#   [Computer Science]  Reinforcement learning learns through rewards and penalties.
#   [Shakespeare]  Reputation is an idle and most false imposition.
#
#   Rank 3  |  distance = 83.5079
#   [Computer Science]  Consistency, availability, and partition tolerance form the CAP theorem.
#   [Shakespeare]  Reputation is an idle and most false imposition.
#
#   Rank 4  |  distance = 85.7817
#   [Computer Science]  Scalability refers to handling increased workload effectively.
#   [Shakespeare]  Sweet are the uses of adversity.
#
#   Rank 5  |  distance = 87.2387
#   [Computer Science]  Greedy algorithms make locally optimal choices.
#   [Shakespeare]  Reputation is an idle and most false imposition.
#
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/overlap/overlap_computer_science_shakespeare.txt
# ================================================================================
# MOST OVERLAPPING SENTENCE PAIRS  —  Theory of Computation  vs  Information Security
# ================================================================================
#
#   ── Full 2880-d Euclidean ──
#
#   Rank 1  |  distance = 119.3422
#   [Theory of Computation]  Alphabets define symbols used in languages.
#   [Information Security]  Worms spread independently across networks.
#
#   Rank 2  |  distance = 119.7635
#   [Theory of Computation]  Alphabets define symbols used in languages.
#   [Information Security]  Trojans disguise themselves as legitimate software.
#
#   Rank 3  |  distance = 119.9991
#   [Theory of Computation]  Encoding allows machines to process other machines.
#   [Information Security]  Tokenization replaces sensitive data with tokens.
#
#   Rank 4  |  distance = 120.0478
#   [Theory of Computation]  Type 3 languages are regular languages.
#   [Information Security]  Dynamic analysis tests running applications.
#
#   Rank 5  |  distance = 120.4595
#   [Theory of Computation]  Alphabets define symbols used in languages.
#   [Information Security]  Biometrics use physical traits for authentication.
#
#   ── PCA-50 Euclidean  (variance explained: 68.3%) ──
#
#   Rank 1  |  distance = 72.4357
#   [Theory of Computation]  Alphabets define symbols used in languages.
#   [Information Security]  Worms spread independently across networks.
#
#   Rank 2  |  distance = 73.7467
#   [Theory of Computation]  Alphabets define symbols used in languages.
#   [Information Security]  Biometrics use physical traits for authentication.
#
#   Rank 3  |  distance = 76.3334
#   [Theory of Computation]  Encoding allows machines to process other machines.
#   [Information Security]  Tokenization replaces sensitive data with tokens.
#
#   Rank 4  |  distance = 78.8888
#   [Theory of Computation]  Diagonalization proves limits of computation.
#   [Information Security]  Behavioral analysis detects unknown threats.
#
#   Rank 5  |  distance = 78.9811
#   [Theory of Computation]  Diagonalization proves limits of computation.
#   [Information Security]  Worms spread independently across networks.
#
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/overlap/overlap_theory_of_computation_information_security.txt
# ================================================================================
# MOST OVERLAPPING SENTENCE PAIRS  —  Hate Speech  vs  No-Hate Speech
# ================================================================================
#
#   ── Full 2880-d Euclidean ──
#
#   Rank 1  |  distance = 45.2203
#   [Hate Speech]  @jaymiller73caca @LyfIsAJourney @KamalaHarris @JoeBiden @BarackObama Exactly. Anyone with common sense can see with their own eyes that this election wasnt rigged. Joe and kamala won fair and square. People are just tired of trump's lies and want a change for the better. That means scrubbing the shit stain out of the carpet in january
#   [No-Hate Speech]  @the_real_mathis @AOC @realDonaldTrump So, back to my original tweet, thank goodness I saw the debate the other night and know NOT to vote for that job-killing anti fracking, oil hating, Joe Biden. I was blinded by Kamala by trump made me see. And Joe is still a racist. https://t.co/3wk36XAaKv
#
#   Rank 2  |  distance = 46.4199
#   [Hate Speech]  @AOC #Trump2020 in person and what about you... you still towing the line for Sleepy Joe OBiden and CumALegsUp Harris???[NEWLINE]#BidenHarris2020 ߤ㰟톰狼
#   [No-Hate Speech]  @realDonaldTrump STOP LYING! YOU are just saying this crap 2get re-elected againߘᰟ衰 . Your time is UP!! Hit the door&amp; get steppin! Biden will be our honorable great new President!! His middle toe has MORE decency than your whole EXISTENCE! #VOTETRUMPOUT #BidenHarris2020 #joebiden #kamalaharris
#
#   Rank 3  |  distance = 50.3577
#   [Hate Speech]  @BrexitBruno @Tomularity @ra1nb0wfa1ry @akattorney @samanthamarika1 @JusBoog88 i have sense and logic. this isn’t about trump. it’s about waking up and not being sheep to the mainstream media that has brainwashed people. Joe and Kamala are corrupt politicians. they’re leftists who use black people for a vote and then forget about them. you’ll see.
#   [No-Hate Speech]  @the_real_mathis @AOC @realDonaldTrump So, back to my original tweet, thank goodness I saw the debate the other night and know NOT to vote for that job-killing anti fracking, oil hating, Joe Biden. I was blinded by Kamala by trump made me see. And Joe is still a racist. https://t.co/3wk36XAaKv
#
#   Rank 4  |  distance = 50.9303
#   [Hate Speech]  Look at this Bullshit!! Biden needs to continue ads and fight to regain our Democracy! @JoeBiden #BidenHarris2020 https://t.co/8lpsEZV2T1
#   [No-Hate Speech]  Change is Coming If You VOTE | Joe Biden and Kamala Harris 2020 https://t.co/zQQ4CQ3Xmm via @YouTube change to be made and Trump needs to go
#
#   Rank 5  |  distance = 51.1267
#   [Hate Speech]  @washingtonpost PLEASE! Like he needs them going up against a brain dead candidate like Joe Biden. Biden will melt down, stutter, stammer and gaffe and you and your MSM pals will still declare him the winner. [NEWLINE][NEWLINE]#Trump2020 #FakeNews
#   [No-Hate Speech]  @the_real_mathis @AOC @realDonaldTrump So, back to my original tweet, thank goodness I saw the debate the other night and know NOT to vote for that job-killing anti fracking, oil hating, Joe Biden. I was blinded by Kamala by trump made me see. And Joe is still a racist. https://t.co/3wk36XAaKv
#
#   ── PCA-50 Euclidean  (variance explained: 68.3%) ──
#
#   Rank 1  |  distance = 21.4372
#   [Hate Speech]  @JohnCornyn I'm going to go ahead and muzzle/mute you. I'm sick of seeing your bullshit on my feed. #VoteHimOut2020 #BidenHarris2020
#   [No-Hate Speech]  @JoeBiden @realDonaldTrump And your point? You wouldn't have been able to stop it either #Trump2020
#
#   Rank 2  |  distance = 22.4144
#   [Hate Speech]  @AOC #Trump2020 in person and what about you... you still towing the line for Sleepy Joe OBiden and CumALegsUp Harris???[NEWLINE]#BidenHarris2020 ߤ㰟톰狼
#   [No-Hate Speech]  @realDonaldTrump STOP LYING! YOU are just saying this crap 2get re-elected againߘᰟ衰 . Your time is UP!! Hit the door&amp; get steppin! Biden will be our honorable great new President!! His middle toe has MORE decency than your whole EXISTENCE! #VOTETRUMPOUT #BidenHarris2020 #joebiden #kamalaharris
#
#   Rank 3  |  distance = 22.8077
#   [Hate Speech]  @jaymiller73caca @LyfIsAJourney @KamalaHarris @JoeBiden @BarackObama Exactly. Anyone with common sense can see with their own eyes that this election wasnt rigged. Joe and kamala won fair and square. People are just tired of trump's lies and want a change for the better. That means scrubbing the shit stain out of the carpet in january
#   [No-Hate Speech]  @the_real_mathis @AOC @realDonaldTrump So, back to my original tweet, thank goodness I saw the debate the other night and know NOT to vote for that job-killing anti fracking, oil hating, Joe Biden. I was blinded by Kamala by trump made me see. And Joe is still a racist. https://t.co/3wk36XAaKv
#
#   Rank 4  |  distance = 23.6125
#   [Hate Speech]  @YGalanter NO they are admitting they went to #Ukraine and got fake info from Russia they are desperate and F up bigly @TuckerCarlsonand Admitting A president went to a foreign country taking the word of Russia #Ukraine to undermine our election ( THAT MEANS ) democrat's were right https://t.co/cP60sDVKOz
#   [No-Hate Speech]  @the_real_mathis @AOC @realDonaldTrump So, back to my original tweet, thank goodness I saw the debate the other night and know NOT to vote for that job-killing anti fracking, oil hating, Joe Biden. I was blinded by Kamala by trump made me see. And Joe is still a racist. https://t.co/3wk36XAaKv
#
#   Rank 5  |  distance = 23.7080
#   [Hate Speech]  I'm sure Trump will help the slimy little scumbag. Hes pretty desperate[NEWLINE][NEWLINE]Lindsey Graham was on Fox on Wednesday night asking for money for the second time in days - pleading with donors to dig deep into their pockets &amp; help him hang onto his South Carolina seat[NEWLINE]#Biden2020 https://t.co/HfTulgVeIU
#   [No-Hate Speech]  @__PrettyTea 2/In order to stop Biden and Kamala from waging war on Black men again, we need Black women such as yourself to keep them out of the White House by not voting. [NEWLINE][NEWLINE]Thanks for sympathizing with the Black man's plight.
#
#   Saved /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences/overlap/overlap_hate_speech_no-hate_speech.txt

# %%
# ============================================================
# CELL 15 — Summary JSON
# ============================================================
summary = {
    "model":         MODEL_NAME,
    "embedding_dim": int(all_embeddings.shape[1]),
    "n_sentences":   {cat: int((all_labels == cat).sum()) for cat in ALL_CATS},
}
with open(os.path.join(RESULTS_DIR, "summary.json"), "w") as f:
    json.dump(summary, f, indent=2)

print(f"\n{'='*60}")
print(f"All results saved to: {RESULTS_DIR}")
print(f"{'='*60}")
# Out:
# ============================================================
# All results saved to: /content/drive/MyDrive/Thesis/results/results_pca_gpt_oss_20b_sentences
# ============================================================
